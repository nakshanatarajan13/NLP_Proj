# %%
import urllib.request
from string import punctuation
from string import whitespace
import numpy as np

# %%
def cleanse(word):
    '''
    This function removes punctuation and whitespace from word,
    the string that we pass as an argument

    Parameters
    word: str

    Returns
    cleaned: str
    '''

    cleaned = '' # we will only include non whitespace, non punctuation characters
    for char in word:
        if ((char in whitespace) or (char in punctuation)):
            pass
        else:
            cleaned += char.lower()
    return cleaned

# %%
def gatherBook(url):
    with urllib.request.urlopen(url) as file_object:
        # *** demarcates actual text of book in gutenberg files
        words = file_object.read().decode('utf-8-sig').split('***')[2]
        words = words.split()
    return words

# %%
if __name__ == '__main__':
    word = 'hey there,. '
    print(cleanse(word))
# Out:
# heythere

# %%
def make_word_dict(word_list):
    '''
    This function will create a dictionary of key-value pairs of form word-wordcount,
    with wordcount being the number of times each respective word appears in word_list

    Parameters
    word_list: list 
        list of words created from full text file, 
        preferably cleansed of punctuation and whitespace
    
    Returns
    myDict: dict 
        dict of key-value pairs of word-wordcount
    
    '''

    myDict = {}
    for word in word_list:
        if word not in myDict:
            myDict[word] = 1 # add word to myDict if word not already in myDict
        else:
            myDict[word] += 1 # increase value += 1 if word already in myDict

    return myDict

# %%
if __name__ == '__main__':
    url = 'http://www.gutenberg.org/cache/epub/61995/pg61995.txt'
    words = gatherBook(url)
    bookDict = make_word_dict(words)
    print(bookDict)
# Out:
# {'Produced': 1, 'by': 215, 'MWS,': 1, 'Martin': 1, 'Pettit': 1, 'and': 2716, 'the': 3441, 'Online': 1, 'Distributed': 1, 'Proofreading': 1, 'Team': 1, 'at': 468, 'https://www.pgdp.net': 1, '(This': 1, 'file': 1, 'was': 1040, 'produced': 6, 'from': 154, 'images': 1, 'generously': 1, 'made': 71, 'available': 2, 'The': 460, 'Internet': 1, 'Archive/American': 1, 'Libraries.)': 1, '[Illustration:': 4, 'With': 6, 'these': 45, 'words,': 12, 'he': 513, 'left': 34, 'somewhat': 18, 'desolate': 4, 'little': 648, 'girl.--_Page': 1, '30._]': 1, 'A': 31, 'GIRL': 3, 'OF': 17, 'HIGH': 2, 'ADVENTURE': 2, 'BY': 3, 'MRS.': 1, 'L.': 2, 'T.': 1, 'MEADE': 1, 'AUTHOR': 1, '"OCEAN\'S': 1, 'GIRLHOOD,"': 1, '"A': 13, 'WILD': 1, 'IRISH': 3, 'GIRL,"': 2, '"THE': 5, 'GIRLS': 4, 'MERTON': 1, 'COLLEGE,"': 1, '"FOR': 1, 'DEAR': 1, 'DAD,"': 1, '"KITTY': 1, 'O\'DONOVAN,"': 1, '"PEGGY': 1, 'FROM': 1, 'KERRY,"': 1, 'CHESTERTON': 1, 'GRADUATES,"': 1, "KING'S": 1, 'ROYAL,"': 1, 'LADY': 1, 'JERRY': 1, "BOY'S": 1, 'DREAMS,"': 1, 'PLUCKY': 1, 'QUEEN': 1, 'JOY,"': 1, 'ETC.,': 1, 'ETC.': 1, '_WITH': 1, 'FOUR': 1, 'HALF-TONE': 1, 'DRAWINGS': 1, 'CHARLES': 1, 'WRENN_': 1, 'NEW': 1, 'YORK': 1, 'HURST': 2, '&': 2, 'COMPANY': 2, 'PUBLISHERS': 1, 'Copyright,': 1, '1914,': 1, 'ILLUSTRATIONS': 1, 'PAGE': 2, 'girl': 60, '_Frontispiece_': 1, 'She': 410, 'nestled': 4, 'more': 86, 'snugly': 4, 'than': 99, 'ever': 54, 'into': 195, 'her': 1190, "grandfather's": 15, 'arms': 17, '100': 2, 'Never': 5, 'there': 129, 'anything': 35, 'quite': 81, 'so': 281, 'delightful': 8, 'as': 452, 'that': 724, 'ride': 25, '207': 1, 'They': 76, 'did': 189, 'find': 21, 'wonderful': 20, 'mosses': 3, '*': 3, 'snow': 2, 'drops': 2, 'even': 58, 'primroses': 6, '349': 2, 'My': 15, 'noble,': 3, 'lovely,': 4, 'Peggy,': 1, 'Let': 6, 'this': 171, 'my': 444, 'First': 1, 'Epistle': 1, 'beg': 1, 'ye,': 29, 'At': 21, 'dawn': 3, 'of': 1775, 'morn,': 1, 'close': 23, 'even,': 1, 'To': 5, 'lift': 2, 'your': 258, 'heart': 47, 'hands': 19, 'to': 2201, 'Heaven.': 5, 'In': 21, 'double': 2, 'duty': 7, 'say': 81, 'prayer;': 1, '"Our': 2, 'Father"': 1, 'first,': 5, 'then': 96, '"_Notre': 1, 'Père_."': 1, 'And,': 1, 'dearest': 8, 'child,': 27, 'along': 15, 'day,': 20, 'everything': 15, 'you': 782, 'do': 177, 'say,': 9, 'Obey': 1, 'please': 7, 'lord': 1, 'lady,': 6, 'So': 17, 'God': 22, 'shall': 50, 'love': 58, 'angels': 5, 'aid': 4, 'ye.': 6, 'If': 29, 'precepts': 1, 'attend,': 1, 'No': 8, 'second': 10, 'letter': 25, 'need': 5, 'I': 1108, 'send,': 1, 'And': 34, 'rest': 17, 'constant': 1, 'friend.': 5, 'MATTHEW': 1, 'PRIOR.': 1, 'CONTENTS.': 1, 'CHAPTER': 25, 'I.': 3, 'THE': 23, 'CHILD': 2, 'WHO': 2, 'WON': 2, 'HEARTS': 1, '1': 1, 'II.': 2, 'VISIT': 2, 'TO': 6, 'IRELAND': 2, '13': 1, 'III.': 2, 'AN': 2, 'CHIEFTAIN': 2, 'AT': 4, 'HOME': 1, '31': 1, 'IV.': 2, 'OLD': 2, 'YOUNG': 2, 'PEOPLE': 1, '49': 1, 'V.': 2, '"I\'LL': 2, 'EXPLAIN': 2, 'YOURSELF"': 1, '68': 1, 'VI.': 2, 'M.': 50, 'LE': 4, 'COMTE': 1, '88': 1, 'VII.': 2, 'LITTLE': 2, 'COMTESSE': 1, 'VIII.': 2, 'BROWN': 2, 'HATS': 2, 'AND': 9, 'FANS': 1, '115': 1, 'IX.': 2, 'ENGLISH': 2, 'SCHOOL': 2, 'LA': 2, 'PRINCESSE': 1, '131': 1, 'X.': 2, 'THOU': 2, 'ART': 2, 'FAITHFUL': 2, 'SO': 2, 'ARE': 2, 'MY': 4, 'BEES': 1, '148': 1, 'XI.': 2, 'THUNDER': 2, 'STORM': 1, '164': 1, 'XII.': 2, 'GEM': 2, 'OCEAN': 1, '180': 1, 'XIII.': 2, 'PINES': 1, '197': 1, 'XIV.': 2, 'STARLIGHT': 2, 'TILLY': 1, '216': 1, 'XV.': 2, 'CANNOT': 2, 'TALK': 2, 'PARLEY-VOUS': 1, '231': 1, 'XVI.': 2, 'FEAR': 2, 'SHILLELAGH': 1, '247': 1, 'XVII.': 2, 'IF': 2, 'IT': 6, 'MUST': 3, 'BE,': 1, '264': 1, 'XVIII.': 2, 'GREEN': 2, 'HAT': 1, '280': 1, 'XIX.': 2, 'CABINET': 2, 'DE': 2, 'BEAUTÉ': 1, '299': 1, 'XX.': 2, 'CONSPIRACY': 1, '314': 1, 'XXI.': 2, 'PALACE': 2, 'TRUTH': 1, '330': 1, 'XXII.': 2, 'IS': 2, 'JOYFUL': 2, 'BEHOLD': 2, 'THEE,': 2, 'PUSHKEEN': 1, '342': 1, 'XXIII.': 2, 'GLORIOUS': 2, 'SOFTNESS': 2, 'XXIV.': 2, 'POUND': 2, 'DAY--A': 2, 'PICTURE': 2, 'WEDDING': 1, '368': 1, 'HEARTS.': 1, 'Marguerite': 12, 'St.' ...

# %%
def make_markov_dict(cleansedWords, n):
    '''
    This function will create a dictionary whose keys are n-word-length prefixes,
    and whose values are lists of 1-word suffixes that follow those prefixes.
    The longer the prefix, the more specific that prefix is, and as such, the value
    corresponding to that prefix, which is a list of suffixes, will be shorter

    the values in this dictionary will be lists of words. These lists, which will 
    include repeats, will help us determine, probabilistically, which word/suffix
    should follow any argued n-word-length prefix

    Parameters
    cleansedWords: list 
        list of words with punctuation and whitespace stripped
    n: int 
        length of prefix that you want to be utilized in markov analysis
    
    Returns
    markovDict: dict 
        dictionary of form key = 'word1 word2...wordn', value = [worda, wordb, wordc, ...]
        where word1 word2...wordn are all possible n-length prefixes gathered from text,
        and worda, wordb,... are all possible suffixes for each of those n-length prefixes

    '''

    preSubList = []
    for i in range(len(cleansedWords) - n):
        preSubList.append(cleansedWords[i:i+n+1])
        # this will create a list of lists of words so we can analyze n-word prefixes
        # so if you want to analyze suffixes for a a 2-word entry, you create a dictionary
        # with all two-word entries as keys, and we'll then enter suffixes as values in that dict
    markovDict = {}
    for _ in preSubList:
        strings = _[0]
        for i in range(1, n):
            strings = strings + ' ' + _[i] # we're creating a string of n-length, which is our prefix length
        if strings not in markovDict:
            markovDict[strings] = [_[n]] #add suffix, which is _[n] to our dictionary
        else:
            markovDict[strings].append(_[n]) # our values are lists, so we append to them if a prefix is already present as a key

    return markovDict

# %%
markovDict
# Out:
# {'Produced by': ['MWS,'],
#  'by MWS,': ['Martin'],
#  'MWS, Martin': ['Pettit'],
#  'Martin Pettit': ['and'],
#  'Pettit and': ['the'],
#  'and the': ['Online',
#   'lesson',
#   'cakes',
#   'best',
#   'stroke',
#   'young',
#   'young',
#   'feeling',
#   'rest',
#   'garden',
#   'housemaid,',
#   'best',
#   'child',
#   'little',
#   'brown',
#   'place',
#   'young',
#   'young',
#   'old',
#   'youngest.',
#   'soft',
#   'time',
#   'pushkeen',
#   'weeks',
#   'youngest',
#   'old',
#   'measles,',
#   'immediate',
#   '_très',
#   'Comte',
#   'young',
#   'young',
#   'good',
#   'head',
#   'robes',
#   'old',
#   'baby',
#   'next',
#   'child',
#   'Comte',
#   'three',
#   'baby',
#   'other',
#   'notary',
#   'Irish,"',
#   'old',
#   'gayest.',
#   'next',
#   'Comtesse',
#   'brown',
#   'woman',
#   'money',
#   'title',
#   'robes',
#   'red',
#   'top',
#   'brilliant',
#   'robes',
#   'chapeaux',
#   'fans',
#   '_gants_',
#   'other',
#   'bees',
#   'abrupt',
#   'doctor',
#   'slim',
#   'bees,',
#   "farmers'",
#   'thin',
#   '_dot_',
#   'lightning',
#   'thunder',
#   'clear,',
#   'air',
#   '_Reparation_,',
#   'wife',
#   'infant',
#   'next',
#   'left',
#   'largest',
#   'old-youngs,',
#   'very',
#   'beautiful',
#   'young-old',
#   'old-young',
#   'Comte,',
#   'fruit',
#   'fruit',
#   'tiny',
#   'rub',
#   'delicious',
#   'curate,',
#   "child's",
#   'man',
#   'girl',
#   'calm,',
#   'people',
#   'place',
#   'old',
#   'beautiful',
#   'new',
#   'red',
#   'other',
#   'punishment',
#   'sailors',
#   'danger',
#   'doctor',
#   'old',
#   'old',
#   'train',
#   'next',
#   'bees',
#   'daintiest."',
#   'hour',
#   'joy',
#   'piano',
#   'grass-green',
#   'grass-green',
#   'scent',
#   'rain',
#   'eyes',
#   'figure',
#   'French',
#   'German',
#   '_géographie_',
#   'artificial',
#   'ladies',
#   'brushing',
#   'delicate',
#   'other',
#   'little',
#   'Marquise',
#   'adventure',
#   'les',
#   'Comte,',
#   'real',
#   'truth',
#   'woman',
#   'after',
#   'baby',
#   'Holy',
#   'angels',
#   'archangels',
#   'first,',
#   'two--the',
#   'young',
#   'beautiful',
#   'primroses',
#   'cabbages',
#   'holy,',
#   'people',
#   'front',
#   'bride',
#   'young',
#   'old',
#   'little'],
#  'the Online': ['Distributed'],
#  'Online Distributed': ['Proofreading'],
#  'Distributed Proofreading': ['Team'],
#  'Proofreading Team': ['at'],
#  'Team at': ['https://www.pgdp.net'],
#  'at https://www.pgdp.net': ['(This'],
#  'https://www.pgdp.net (This': ['file'],
#  '(This file': ['was'],
#  'file was': ['produced'],
#  'was produced': ['from', 'in'],
#  'produced from': ['images'],
#  'from images': ['generously'],
#  'images generously': ['made'],
#  'generously made': ['available'],
#  'made available': ['by'],
#  'available by': ['The'],
#  'by The': ['Internet',
#   'Desmond',
#   "Desmond's",
#   "Desmond's",
#   'Desmond.',
#   'Desmond'],
#  'The Internet': ['Archive/American'],
#  'Internet Archive/American': ['Libraries.)'],
#  'Archive/American Libraries.)': ['[Illustration:'],
#  'Libraries.) [Illustration:': ['With'],
#  '[Illustration: With': ['these'],
#  'With these': ['words,', 'words,', 'she', 'words'],
#  'these words,': ['he', 'he', 'his'],
#  'words, he': ['left', 'left'],
#  'he left': ['the', 'the', 'the', 'in,', 'her'],
#  'left the': ['somewhat',
#   'somewhat',
#   'somewhat',
#   'room.',
#   'study;',
#   'room.',
#   'room.',
#   '_établissement_',
#   'grounds',
#   'stables,',
#   'room.',
#   'room.'],
#  'the somewhat': ['desolate', 'desolate', 'desolate'],
#  'somewhat desolate': ['little', 'little', 'little'],
#  'desolate little': ['girl.--_Page', 'girl', 'girl.'],
#  'little girl.--_Page': ['30._]'],
#  'girl.--_Page 30._]': ['A'],
#  '30._] A': ['GIRL'],
#  'A GIRL': ['OF', 'OF'],
#  'GIRL OF': ['HIGH', 'HIGH'],
#  'OF HIGH': ['ADVENTURE', 'ADVENTURE'],
#  'HIGH ADVENTURE': ['BY', 'CHAPTER'],
#  'ADVENTURE BY': ['MRS.'],
#  'BY MRS.': ['L.'],
#  'MRS. L.': ['T.'],
#  'L. T.': ['MEADE'],
#  'T. MEADE': ['AUTHOR'],
#  'MEADE AUTHOR': ['OF'],
#  'AUTHOR OF': ['"OCEAN\'S'],
#  'OF "OCEAN\'S': ['GIRLHOOD,"'],
#  '"OCEAN\'S GIRLHOOD,"': ['"A'],
#  'GIRLHOOD," "A': ['WILD'],
#  '"A WILD': ['IRISH'],
#  'WILD IRISH': ['GIRL,"'],
#  'IRISH GIRL,"': ['"THE'],
#  'GIRL," "THE': ['GIRLS', 'QUEEN'],
#  '"THE GIRLS': ['OF', 'OF'],
#  'GIRLS OF': ['MERTON', "KING'S"],
#  'OF MERTON': ['COLLEGE,"'],
#  'MERTON COLLEGE,"': ['"FOR'],
#  'COLLEGE," "FOR': ['DEAR'],
#  '"FOR DEAR': ['DAD,"'],
#  'DEAR DAD,"': ['"KITTY'],
#  'DAD," "KITTY': ['O\'DONOVAN,"'],
#  '"KITTY O\'DONOVAN,"': ['"PEGGY'],
#  'O\'DONOVAN," "PEGGY': ['FROM'],
#  '"PEGGY FROM': ['KERRY,"'],
#  'FROM KERRY,"': ['"THE'],
#  'KERRY," "THE': ['CHESTERTON'],
#  '"THE CHESTERTON': ['GIRL'],
#  'CHESTERTON GIRL': ['GRADUATES,"'],
#  'GIRL GRADUATES,"': ['"THE'],
#  'GRADUATES," "THE': ['GIRLS'],
#  "OF KING'S": ['ROYAL,"'],
#  'KING\'S ROYAL,"': ['"THE'],
#  'ROYAL," "THE': ['LADY'],
#  '"THE LADY': ['OF'],
#  'LADY OF': ['JERRY'],
#  'OF JERRY': ["BOY'S"],
#  "JERRY BOY'S": ['DREAMS,"'],
#  'BOY\'S DREAMS,"': ['"A'],
#  'DREAMS," "A': ['PLUCKY'],
#  '"A PLUCKY': ['GIRL,"'],
#  'PLUCKY GIRL,"': ['"THE'],
#  '"THE QUEEN': ['OF'],
#  'QUEEN OF': ['JOY,"'],
#  'OF JOY,"': ['ETC.,'],
#  'JOY," ETC.,': ['ETC.'],
#  'ETC., ETC.': ['_WITH'],
#  'ETC. _WITH': ['FOUR'],
#  '_WITH FOUR': ['HALF-TONE'],
#  'FOUR HALF-TONE': ['DRAWINGS'],
#  'HALF-TONE DRAWINGS': ['BY'],
#  'DRAWINGS BY': ['CHARLES'],
#  'BY CHARLES': ['L.'],
#  'CHARLES L.': ['WRENN_'],
#  'L. WRENN_': ['NEW'],
#  'WRENN_ NEW': ['YORK'],
#  'NEW YORK': ['HURST'],
#  'YORK HURST': ['&'],
#  'HURST &': ['COMPANY', 'COMPANY'],
#  '& COMPANY': ['PUBLISHERS', 'ILLUSTRATIONS'],
#  'COMPANY PUBLISHERS': ['Copyright,'],
#  'PUBLISHERS Copyright,': ['1914,'],
#  'Copyright, 1914,': ['BY'],
#  '1914, BY': ['HURST'],
#  'BY HURST': ['&'],
#  'COMPANY ILLUSTRATIONS': ['PAGE'],
#  'ILLUSTRATIONS PAGE': ['With'],
#  'PAGE With': ['these'],
#  'little girl': ['_Frontispiece_',
#   'used',
#   'and',
#   'I',
#   'to',
#   'and',
#   'a',
#   'and',
#   'out',
#   'to',
#   'entered',
#   'rejoiced',
#   'out',
#   'and',
#   'on',
#   'ought',
#   'told',
#   'together."'],
#  'girl _Frontispiece_': ['She'],
#  '_Frontispiece_ She': ['nestled'],
#  'She nestled': ['more', 'more'],
#  'nestled more': ['snugly', 'snugly', 'snugly'],
#  'more snugly': ['than', 'than', 'than'],
#  'snugly than': ['ever', 'ever', 'ever'],
#  'than ever': ['into',
#   'as',
#   '"_When',
#   'and',
#   'when',
#   'into',
#   'into',
#   'to',
#   'the',
#   'now.'],
#  'ever into': ['her', 'her', 'her'],
#  'into her': ["grandfather's",
#   'eyes.',
#   'little',
#   'brilliant,',
#   "uncle's",
#   'cheeks',
#   "father's",
#   "grandfather's",
#   "grandfather's",
#   'face."',
#   'hair,',
#   'private',
#   'saddle',
#   "grandfather's",
#   'own',
#   'little',
#   "grandfather's",
#   'dress,'],
#  "her grandfather's": ['arms',
#   'arms',
#   'arms.--_Page',
#   'presence',
#   'knee.',
#   'room,',
#   'room,',
#   'knee',
#   'unaccountable',
#   'arms.',
#   'knee.'],
#  "grandfather's arms": ['100', 'and'],
#  'arms 100': ['Never'],
#  '100 Never': ['was'],
#  'Never was': ['there', 'there'],
#  'was there': ['anything', 'to', 'anything', 'anything', 'with'],
#  'there anything': ['quite', 'quite', 'quite'],
#  'anything quite': ['so', 'so', 'so', 'so'],
#  'quite so': ['delightful',
#   'dark,',
#   'foolish,"',
#   'dear',
#   'sweet',
#   'tight.',
#   'much',
#   'delightful',
#   'delightful',
#   'easily.',
#   'good',
#   'ignorant,'],
#  'so delightful': ['as', 'to', 'as', 'as'],
#  'delightful as': ['that', 'that', 'that'],
#  'as that': ['ride', 'I', 'ride', 'ride.--_Page', 'wicked', '_jeune'],
#  'that ride': ['207', 'to'],
#  'ride 207': ['They'],
#  '207 They': ['did'],
#  'They did': ['find', 'not', 'not', 'find', 'not'],
#  'did find': ['wonderful', 'wonderful', 'wonderful'],
#  'find wonderful': ['mosses', 'mosses,', 'mosses'],
#  'wonderful mosses': ['and', 'and'],
#  'mosses and': ['*', 'snow'],
#  'and *': ['*'],
#  '* *': ['*', 'snow'],
#  '* snow': ['drops'],
#  'snow drops': ['and', 'and'],
#  'drops and': ['even', 'even'],
#  'and even': ['primroses',
#   'provided',
#   'the',
#   'distinguished',
#   'have',
#   'the',
#   'the',
#   'when',
#   'with',
#   '_they_',
#   'primroses.',
#   'primroses.--_Page'],
#  'even primroses': ['349'],
#  'primroses 349': ['My'],
#  '349 My': ['noble,'],
#  'My noble,': ['lovely,'],
#  'noble, lovely,': ['little'],
#  'lovely, little': ['Peggy,'],
#  'little Peggy,': ['Let'],
#  'Peggy, Let': ['this'],
#  'Let this': ['my'],
#  'this my': ['First'],
#  'my First': ['Epistle'],
#  'First Epistle': ['beg'],
#  'Epistle beg': ['ye,'],
#  'beg ye,': ['At'],
#  'ye, At': ['dawn'],
#  'At dawn': ['of'],
#  'dawn of': ['morn,', 'day', 'day,'],
#  'of morn,': ['and'],
#  'morn, and': ['close'],
#  'and close': ['of', 'at'],
#  'close of': ['even,'],
#  'of even,': ['To'],
#  'even, To': ['lift'],
#  'To lift': ['your'],
#  'lift your': ['heart'],
#  'your heart': ['and', 'is', 'burst.', 'to', 'a-breaking?"'],
#  'heart and': ['hands', 'the', 'a'],
#  'and hands': ['to'],
#  'hands to': ['Heaven.'],
#  'to Heaven.': ['In', 'There,'],
#  'Heaven. In': ['double'],
#  'In double': ['duty'],
#  'double duty': ['say'],
#  'duty say': ['your'],
#  'say your': ['prayer;', 'name', 'hymn'],
#  'your prayer;': ['"Our'],
#  'prayer; "Our': ['Father"'],
#  '"Our Father"': ['first,'],
#  'Father" first,': ['then'],
#  'first, then': ['"_Notre'],
#  'then "_Notre': ['Père_."'],
#  '"_Notre Père_."': ['And,'],
#  'Père_." And,': ['dearest'],
#  'And, dearest': ['child,'],
#  'dearest child,': ['along'],
#  'child, along': ['the'],
#  'along the': ['day,', 'road', 'highroad', 'deck'],
#  'the day,': ['In'],
#  'day, In': ['everything'],
#  'In everything': ['you'],
#  'everything you': ['do'],
#  'you do': ['and', 'not', 'indeed', 'look', 'and', 'know,', 'not', 'it'],
#  'do and': ['say,', 'you', 'when', 'we'],
#  'and say,': ['Obey'],
#  'say, Obey': ['and'],
#  'Obey and': ['please'],
#  'and please': ['my', 'come'],
#  'please my': ['lord'],
#  'my lord': ['and'],
#  'lord and': ['lady,'],
#  'and lady,': ['So'],
#  'lady, So': ['God'],
#  'So God': ['shall'],
#  'God shall': ['love'],
#  'shall love': ['and'],
#  'love and': ['angels', 'the'],
#  'and angels': ['aid'],
#  'angels aid': ['ye.'],
#  'aid ye.': ['If'],
#  'ye. If': ['to'],
#  'If to': ['these'],
#  'to these': ['precepts', 'pins'],
#  'these precepts': ['you'],
#  'precepts you': ['attend,'],
#  'you attend,': ['No'],
#  'attend, No': ['second'],
#  'No second': ['letter'],
#  'second letter': ['need'],
#  'letter need': ['I'],
#  'need I': ['send,'],
#  'I send,': ['And'],
#  'send, And': ['so'],
#  'And so': ['I', 'this'],
#  'so I': ['rest', 'said', 'thought', 'got', 'thought', 'have'],
#  'I rest': ['your'],
#  'rest your': ['constant'],
#  'your constant': ['friend.'],
#  'constant friend.': ['MATTHEW'],
#  'friend. MATTHEW': ['PRIOR.'],
#  'MATTHEW PRIOR.': ['CONTENTS.'],
#  'PRIOR. CONTENTS.': ['CHAPTER'],
#  'CONTENTS. CHAPTER': ['PAGE'],
#  'CHAPTER PAGE': ['I.'],
#  'PAGE I.': ['THE'],
#  'I. THE': ['CHILD', 'CHILD'],
#  'THE CHILD': ['WHO', 'WHO'],
#  'CHILD WHO': ['WON', 'WON'],
#  'WHO WON': ['HEARTS', 'HEARTS.'],
#  'WON HEARTS': ['1'],
#  'HEARTS 1': ['II.'],
#  '1 II.': ['A'],
#  'II. A': ['VISIT', 'VISIT'],
#  'A VISIT': ['TO', 'TO'],
#  'VISIT TO': ['IRELAND', 'IRELAND.'],
#  'TO IRELAND': ['13'],
#  'IRELAND 13': ['III.'],
#  '13 III.': ['AN'],
#  'III. AN': ['IRISH', 'IRISH'],
#  'AN IRISH': ['CHIEFTAIN', 'CHIEFTAIN'],
#  'IRISH CHIEFTAIN': ['AT', 'AT'],
#  'CHIEFTAIN AT': ['HOME', 'HOME.'],
#  'AT HOME': ['31'],
#  'HOME 31': ['IV.'],
#  '31 IV.': ['OLD'],
#  'IV. OLD': ['YOUNG', 'YOUNG'],
#  'OLD YOUNG': ['PEOPLE', 'PEOPLE.'],
#  'YOUNG PEOPLE': ['49'],
#  'PEOPLE 49': ['V.'],
#  '49 V.': ['"I\'LL'],
#  'V. "I\'LL': ['EXPLAIN', 'EXPLAIN'],
#  '"I\'LL EXPLAIN': ['TO', 'TO'],
#  'EXPLAIN TO': ['YOURSELF"', 'YOURSELF."'],
#  'TO YOURSELF"': ['68'],
#  'YOURSELF" 68': ['VI.'],
#  '68 VI.': ['M.'],
#  'VI. M.': ['LE', 'LE'],
#  'M. LE': ['COMTE', 'COMTE.'],
#  'LE COMTE': ['88'],
#  'COMTE 88': ['VII.'],
#  '88 VII.': ['THE'],
#  'VII. THE': ['LITTLE', 'LITTLE'],
#  'THE LITTLE': ['COMTESSE', 'COMTESSE.'],
#  'LITTLE COMTESSE': ['100'],
#  'COMTESSE 100': ['VIII.'],
#  '100 VIII.': ['BROWN'],
#  'VIII. BROWN': ['HATS', 'HATS'],
#  'BROWN HATS': ['AND', 'AND'],
#  'HATS AND': ['FANS', 'FANS.'],
#  'AND FANS': ['115'],
#  'FANS 115': ['IX.'],
#  '115 IX.': ['THE'],
#  'IX. THE': ['ENGLISH', 'ENGLISH'],
#  'THE ENGLISH': ['GIRLS', 'GIRLS'],
#  'ENGLISH GIRLS': ['AT', 'AT'],
#  'GIRLS AT': ['THE', 'THE'],
#  'AT THE': ['SCHOOL', 'SCHOOL'],
#  'THE SCHOOL': ['OF', 'OF'],
#  'SCHOOL OF': ['LA', 'LA'],
#  'OF LA': ['PRINCESSE', 'PRINCESSE.'],
#  'LA PRINCESSE': ['131'],
#  'PRINCESSE 131': ['X.'],
#  '131 X.': ['THOU'],
#  'X. THOU': ['ART', 'ART'],
#  'THOU ART': ['FAITHFUL', 'FAITHFUL'],
#  'ART FAITHFUL': ['AND', 'AND'],
#  'FAITHFUL AND': ['SO', 'SO'],
#  'AND SO': ['ARE', 'ARE'],
#  'SO ARE': ['MY', 'MY'],
#  'ARE MY': ['BEES', 'BEES.'],
#  'MY BEES': ['148'],
#  'BEES 148': ['XI.'],
#  '148 XI.': ['THUNDER'],
#  'XI. THUNDER': ['STORM', 'STORM.'],
#  'THUNDER STORM': ['164'],
#  'STORM 164': ['XII.'],
#  '164 XII.': ['GEM'],
#  'XII. GEM': ['OF', 'OF'],
#  'GEM OF': ['THE', 'THE'],
#  'OF THE': ['OCEAN', 'SHILLELAGH', 'OCEAN.', 'SHILLELAGH.'],
#  'THE OCEAN': ['180'],
#  'OCEAN 180': ['XIII.'],
#  '180 XIII.': ['THE'],
#  'XIII. THE': ['PINES', 'PINES.'],
#  'THE PINES': ['197'],
#  'PINES 197': ['XIV.'],
#  '197 XIV.': ['STARLIGHT'],
#  'XIV. STARLIGHT': ['AND', 'AND'],
#  'STARLIGHT AND': ['TILLY', 'TILLY.'],
#  'AND TILLY': ['216'],
#  'TILLY 216': ['XV.'],
#  '216 XV.': ['I'],
#  'XV. I': ['CANNOT', 'CANNOT'],
#  'I CANNOT': ['TALK', 'TALK'],
#  'CANNOT TALK': ['PARLEY-VOUS', 'PARLEY-VOUS.'],
#  'TALK PARLEY-VOUS': ['231'],
#  'PARLEY-VOUS 231': ['XVI.'],
#  '231 XVI.': ['THE'],
#  'XVI. THE': ['FEAR', 'FEAR'],
#  'THE FEAR': ['OF', 'OF'],
#  'FEAR OF': ['THE', 'THE'],
#  'THE SHILLELAGH': ['247'],
#  'SHILLELAGH 247': ['XVII.'],
#  '247 XVII.': ['IF'],
#  'XVII. IF': ['IT', 'IT'],
#  'IF IT': ['MUST', 'MUST'],
#  'IT MUST': ['BE,', '264', 'BE'],
#  'MUST BE,': ['IT'],
#  'BE, IT': ['MUST'],
#  'MUST 264': ['XVIII.'],
#  '264 XVIII.': ['THE'],
#  'XVIII. THE': ['GREEN', 'GREEN'],
#  'THE GREEN': ['HAT', 'HAT.'],
#  'GREEN HAT': ['280'],
#  'HAT 280': ['XIX.'],
#  '280 XIX.': ['LE'],
#  'XIX. LE': ['CABINET', 'CABINET'],
#  'LE CABINET': ['DE', 'DE'],
#  'CABINET DE': ['BEAUTÉ', 'BEAUTÉ.'],
#  'DE BEAUTÉ': ['299'],
#  'BEAUTÉ 299': ['XX.'],
#  '299 XX.': ['A'],
#  'XX. A': ['CONSPIRACY', 'CONSPIRACY.'],
#  'A CONSPIRACY': ['314'],
#  'CONSPIRACY 314': ['XXI.'],
#  '314 XXI.': ['THE'],
#  'XXI. THE': ['PALACE', 'PALACE'],
#  'THE PALACE': ['OF', 'OF'],
#  'PALACE OF': ['TRUTH', 'TRUTH.'],
#  'OF TRUTH': ['330'],
#  'TRUTH 330': ['XXII.'],
#  '330 XXII.': ['IT'],
#  'XXII. IT': ['IS', 'IS'],
#  'IT IS': ['JOYFUL', 'JOYFUL'],
#  'IS JOYFUL': ['TO', 'TO'],
#  'JOYFUL TO': ['BEHOLD', 'BEHOLD'],
#  'TO BEHOLD': ['THEE,', 'THEE,'],
#  'BEHOLD THEE,': ['MY', 'MY'],
#  'THEE, MY': ['PUSHKEEN', 'PUSHKEEN.'],
#  'MY PUSHKEEN': ['342'],
#  'PUSHKEEN 342': ['XXIII.'],
#  '342 XXIII.': ['THE'],
#  'XXIII. THE': ['GLORIOUS', 'GLORIOUS'],
#  'THE GLORIOUS': ['SOFTNESS', 'SOFTNESS'],
#  'GLORIOUS SOFTNESS': ['OF', 'OF'],
#  'SOFTNESS OF': ['IRELAND', 'IRELAND.'],
#  'OF IRELAND': ['349'],
#  'IRELAND 349': ['XXIV.'],
#  '349 XXIV.': ['A'],
#  'XXIV. A': ['POUND', 'POUND'],
#  'A POUND': ['A', 'A'],
#  'POUND A': ['DAY--A', 'DAY--A'],
#  'A DAY--A': ['PICTURE', 'PICTURE'],
#  'DAY--A PICTURE': ['AND', 'AND'],
#  'PICTURE AND': ['A', 'A'],
#  'AND A': ['WEDDING', 'WEDDING.'],
#  'A WEDDING': ['368'],
#  'WEDDING 368': ['A'],
#  '368 A': ['GIRL'],
#  'ADVENTURE CHAPTER': ['I.'],
#  'CHAPTER I.': ['THE'],
#  'WON HEARTS.': ['Marguerite'],
#  'HEARTS. Marguerite': ['St.'],
#  'Marguerite St.': ['Juste', 'Juste.', 'Juste.', 'Juste,', 'Juste'],
#  'St. Juste': ['was',
#   'found',
#   'had,',
#   'slept',
#   'and',
#   'live?"',
#   'and',
#   'was',
#   'of',
#   'was',
#   'quickly',
#   'drove',
#   'and',
#   'to',
#   'took',
#   'used',
#   'were',
#   'imagine',
#   'a',
#   'that',
#   'would.',
#   "didn't",
#   'and',
#   'married',
#   'looked',
#   'was',
#   'required',
#   'was',
#   'had',
#   'was'],
#  'Juste was': ['Irish', 'the', 'making', 'a', 'less', 'shut'],
#  'was Irish': ['on'],
#  'Irish on': ['her'],
#  'on her': ["mother's",
#   "uncle's",
#   'like',
#   "uncle's",
#   'unexpected',
#   'marriage',
#   'small',
#   'white',
#   'way',
#   'soft',
#   'back.',
#   "grandfather's",
#   'nondescript',
#   'face,',
#   'own',
#   'face.',
#   'hideous',
#   "father's",
#   'the',
#   'knees',
#   'last',
#   "grandfather's",
#   'feet.',
#   'arm.',
#   'little',
#   "grandfather's"],
#  "her mother's": ['side,', 'people', 'child?"', 'side,'],
#  "mother's side,": ['who', 'but'],
#  'side, who': ['was'],
#  'who was': ['born',
#   'really',
#   'the',
#   'addressed',
#   'his',
#   'becoming',
#   'one',
#   'real--real',
#   'a',
#   'totally',
#   'not',
#   'so',
#   'to',
#   'in',
#   'so',
#   'altogether',
#   'enjoying',
#   'now',
#   'feeling',
#   'watching',
#   'furious',
#   'always',
#   'only',
#   'on',
#   'too',
#   'so',
#   'also',
#   'standing',
#   'holding',
#   'one',
#   'a'],
#  'was born': ['of', 'that'],
#  'born of': ['the', 'my'],
#  'of the': ['Desmonds',
#   'victims',
#   'guillotine.',
#   'merry',
#   'heart',
#   'grave,',
#   'state',
#   'room',
#   'feast',
#   'Desmonds,',
#   'matter.',
#   'boys,',
#   'old',
#   'study',
#   'Rev.',
#   'coast',
#   'little',
#   "morning'?",
#   'county',
#   'eggs',
#   'year',
#   "birds'",
#   'said',
#   'scene',
#   'cart',
#   'said',
#   'aged',
#   'profits.',
#   'old',
#   'support',
#   'sensation',
#   'old',
#   'servants',
#   'other,',
#   'last',
#   'way',
#   'fact',
#   'Misses',
#   'avenue,',
#   'great',
#   'Almighty',
#   'longing',
#   'Almighty',
#   'best',
#   'time',
#   'servants',
#   'room.',
#   'room.',
#   'wee',
#   'man',
#   'child.',
#   'windows',
#   'fact',
#   'bed',
#   'room--superintended',
#   'three',
#   'little',
#   "child's",
#   'green,',
#   'Desmonds',
#   'Desmonds',
#   'little',
#   'French',
#   'house',
#   'old',
#   'true',
#   'best',
#   'meadows',
#   'tumble-down',
#   'Holy',
#   'British',
#   'good',
#   'best,',
#   'life',
#   'whole',
#   'old',
#   'little',
#   'matter',
#   'old',
#   'bargain."',
#   'little',
#   'nest,',
#   'sweet',
#   'bit',
#   'French',
#   'accursed',
#   '_chapeaux_',
#   'most',
#   'beautiful',
#   'good',
#   'room.',
#   'face,',
#   'head',
#   'most',
#   'little',
#   'title',
#   'rarest.',
#   'old',
#   'wide',
#   'celebrated',
#   'place.',
#   'Desmonds',
#   'Lord',
#   'best,',
#   'Almighty."',
#   'château',
#   'very',
#   'château,',
#   'English',
#   'windows',
#   'French',
#   'astonishing',
#   'blessed',
#   'age',
#   'good',
#   'most',
#   'most',
#   'funniest.',
#   'youngest',
#   'very',
#   'time.',
#   'shop',
#   '_ancienne',
#   'most',
#   'red-faced',
#   'red',
#   'Comtesse,"',
#   'most',
#   'French',
#   'very',
#   'château.',
#   'little',
#   '_ancienne',
#   '_chic_.',
#   'many',
#   'world',
#   'same',
#   'best',
#   'same',
#   'room.',
#   'little',
#   'Marquis.',
#   'bright',
#   'Marquis',
#   'motor',
#   'room.',
#   'best',
#   '_établissement_,',
#   'question,',
#   'little',
#   'very',
#   'little',
#   'most',
#   'noblest,',
#   'school',
#   'great',
#   'small',
#   'marriage',
#   'farmer',
#   'largest',
#   'most',
#   'different',
#   'most',
#   'St.',
#   'taste',
#   'little',
#   '_établissement_.',
#   'English',
#   'present',
#   'garden',
#   'most',
#   '_établissement_',
#   'farmers',
#   '_salon_',
#   'French',
#   'most',
#   'farmers.',
#   'awful',
#   'holy',
#   'smiling',
#   'Holy',
#   'child',
#   'adorable',
#   'beautiful,"',
#   'nerves,',
#   'justice',
#   'French',
#   'French',
#   'straight',
#   'French',
#   'road.',
#   'Château',
#   'room',
#   'most',
#   'French',
#   'ocean,',
#   'sea,"',
#   'job.',
#   'pushkeen',
#   'bonfires;',
#   'bags',
#   'avenue,',
#   'generous',
#   'room',
#   'ramshackle',
#   'very',
#   'excellent',
#   'old-youngs?"',
#   'French',
#   'Church',
#   'famous',
#   'night',
#   'future',
#   'soil,',
#   'soil.',
#   'year.',
#   'little',
#   'whitest',
#   'old',
#   'stables.',
#   'Desmonds',
#   'beautiful',
#   'sweet',
#   'nonsense',
#   'Desmonds_',
#   'old',
#   'room,',
#   'time',
#   'stall,',
#   'new',
#   'stable.',
#   'pins',
#   'grooms,',
#   'new',
#   'thing',
#   'Rayneses."',
#   'Rayneses',
#   'saddle',
#   'lovely',
#   'pins,',
#   'shop',
#   'other,',
#   'pins',
#   'ten',
#   'board',
#   'narrative,',
#   'house.',
#   'room.',
#   'jolly.',
#   'Cork',
#   'noise',
#   'place.',
#   'shop,',
#   'Desmonds,',
#   'bottom',
#   'sea.',
#   'Desmonds',
#   'little',
#   'words.',
#   'very',
#   'berth.',
#   'deep,',
#   'berth.',
#   'awful',
#   'letter',
#   'thoroughbred',
#   'pushkeen',
#   'little',
#   'bed',
#   'coal-merchant',
#   'Irish',
#   'old',
#   'country.',
#   'Emerald',
#   'name',
#   'eye.',
#   'beast."',
#   'pins',
#   'creature.',
#   'man',
#   'clean,',
#   'children,',
#   'power',
#   'celebrated',
#   'room.',
#   'thing;',
#   'air',
#   'land',
#   'shillelagh.',
#   'Desmonds_',
#   'inevitable',
#   'little',
#   'old,',
#   'best',
#   'Desmonds_',
#   'little',
#   'Almighty."',
#   'carriage',
#   'most',
#   '_grande',
#   'love,',
#   'singing,',
#   'grandpères',
#   'handsome',
#   'Irish',
#   'most',
#   'Desmonds',
#   'very',
#   'blessed,"',
#   'time',
#   'French--yes--of',
#   'big',
#   'little',
#   'great',
#   'same',
#   'excellence',
#   'hat.',
#   'black,',
#   'said',
#   'child',
#   'people',
#   'aristocrats.',
#   'aristocrats.',
#   'Irish',
#   'pushkeen',
#   'dreadful',
#   'south',
#   'little',
#   'greatest,',
#   'old',
#   'violets,',
#   'roses,',
#   'sweet',
#   'trees',
#   'St.',
#   'serious?"',
#   'little',
#   'French.',
#   'day."',
#   'aged',
#   'people',
#   'marvellous.',
#   'best',
#   'education',
#   'utmost',
#   'clock,',
#   'hands.',
#   'high',
#   'girls',
#   'faded-looking',
#   'day',
#   'hair',
#   'hope,"',
#   'most',
#   'late',
#   'rare',
#   'taste',
#   '_toilette_,',
#   'noblesse.',
#   'Marquis',
#   'whole',
#   '_établissement_;',
#   'peach',
#   'most',
#   'Parisian',
#   'spring,',
#   'Marquise',
#   'Marquise',
#   'best.',
#   'ugly',
#   '_magasin_',
#   'very',
#   'one',
#   '_établissement_',
#   'room."',
#   'best.',
#   'room.',
#   'French',
#   "doctor's",
#   'jealous',
#   'cruel',
#   'cruel',
#   'brightness',
#   'morning.',
#   'day;',
#   'bed,',
#   'scent',
#   'dead',
#   'Kingdom',
#   'extent',
#   'funds',
#   'Château',
#   'future.',
#   'one',
#   'purest',
#   'weary.',
#   '_établissement_',
#   'fields.',
#   'fructification',
#   'moss',
#   'county',
#   'old',
#   'child.',
#   'fir',
#   'blush,',
#   'hearts',
#   'dear',
#   'choicest',
#   'Church',
#   'neighbourhood',
#   'little',
#   'Church',
#   'childer?"',
#   'study,',
#   'Desmonds.',
#   'year',
#   'aged.',
#   'wardrobe',
#   'bride.',
#   "bride's",
#   'board,',
#   'old',
#   'guests',
#   'holy',
#   'proceeds',
#   'little',
#   'Romney.'],
#  'the Desmonds': ['of',
#   'were',
#   'of',
#   'about',
#   'falling',
#   'disgracing',
#   'married',
#   'of',
#   'were',
#   'a',
#   'and',
#   'did',
#   'never',
#   'forever;'],
#  'Desmonds of': ['Desmondstown',
#   'Desmondstown.',
#   'Desmondstown!',
#   'Desmondstown.'],
#  'of Desmondstown': ['in', 'and', 'when', 'and', "don't", 'was'],
#  'Desmondstown in': ['the', 'the', 'time', 'a', 'the'],
#  'in the': ['County',
#   'least',
#   'great',
#   'Château',
#   'least',
#   'least',
#   'county."',
#   'highest',
#   'morning',
#   'county',
#   'cab.',
#   'train,',
#   'world',
#   'whole',
#   'county."',
#   'ould',
#   'morning."',
#   'station',
#   'train.',
#   'county."',
#   'evening,',
#   'springless',
#   'county,',
#   'neighbourhood.',
#   'air,',
#   'whole',
#   'name',
#   'smoking-room.',
#   'preparation',
#   'fresh',
#   'home',
#   'house',
#   'midst',
#   'front',
#   'world',
#   'county."',
#   'house."',
#   'evening.',
#   'house."',
#   'county.',
#   'broken-down',
#   'breadth',
#   'world',
#   'Rev.',
#   'highest',
#   'house,',
#   'hall.',
#   'little',
#   'hall.',
#   'hall.',
#   'world',
#   'thick',
#   'air.',
#   'words,',
#   'other',
#   'old',
#   'money--the',
#   'hall.',
#   'matter,',
#   'same',
#   'horse-pond,',
#   'horse-pond,',
#   'house',
#   'beautiful',
#   'stately',
#   'direction',
#   'world,',
#   'world."',
#   'English',
#   'world.',
#   'French',
#   'world',
#   'shop.',
#   'excitement',
#   'making',
#   'despair',
#   'other',
#   'French',
#   'shop.',
#   'direction',
#   'French',
#   '_établissement_',
#   'château',
#   'true',
#   'least',
#   'tumble-down',
#   'best',
#   'school.',
#   'old',
#   'shop',
#   'afternoon',
#   'shop,',
#   'wide',
#   '_établissement_',
#   'blue',
#   'choosing',
#   'centre',
#   'air',
#   'morning',
#   'ancient',
#   'garden',
#   'whole',
#   'francs',
#   'francs',
#   'garden',
#   'direction',
#   '_établissement_,',
#   'world.',
#   'New',
#   '_établissement_',
#   'sight',
#   'hall',
#   'best',
#   'whole',
#   'least.',
#   'end',
#   'early',
#   'morning,',
#   'distance',
#   'morning',
#   'thrain,',
#   'room',
#   'room',
#   'most',
#   'school',
#   'shop--and',
#   'window,',
#   'wall',
#   'ugliest',
#   'great',
#   'world--the',
#   'dark',
#   'life',
#   'hands',
#   'presence',
#   'old',
#   'small,',
#   'stable,',
#   'vicinity',
#   'world.',
#   'place,',
#   'Corner,"',
#   'distant',
#   'porch,',
#   'lining',
#   'highest',
#   'highest',
#   'best',
#   'art',
#   'whole',
#   'nest',
#   'least',
#   'air,',
#   'loose',
#   'pins.',
#   'least',
#   'thick',
#   'world,',
#   'passage',
#   'wide,',
#   'opposite',
#   'story',
#   'nearer',
#   'far',
#   'midst',
#   'train.',
#   'world',
#   'neat,',
#   'least',
#   'room,',
#   'room,',
#   'footsteps',
#   'matter',
#   'least',
#   'saddle',
#   'loose',
#   'saddle,',
#   'countryside',
#   'complete',
#   'house',
#   'air,',
#   'air',
#   'first',
#   'uncomfortable',
#   'old',
#   'world,',
#   'world.',
#   'corner',
#   'hall',
#   'shop.',
#   '_établissement_.',
#   'love',
#   'garden,',
#   'proper',
#   'shop."',
#   '_établissement_,',
#   'breast',
#   'wide,',
#   'least',
#   '_établissement_,',
#   '_établissement,',
#   'least',
#   'school',
#   'Boulevard',
#   'act.',
#   'blackness',
#   'least',
#   '_établissement_',
#   'act,',
#   'County',
#   'beautiful',
#   'livery',
#   'mouth!',
#   'future.',
#   'gentle,',
#   '_établissement_',
#   '_établissement_',
#   'lodge',
#   '_établissement_,"',
#   'world.',
#   'world.',
#   'least',
#   'hands',
#   'world,',
#   'town',
#   'French',
#   'highest',
#   'aristocratic',
#   'grass."',
#   'grass',
#   'sun.',
#   'sun;',
#   'grass',
#   '_établissement_',
#   'morning,',
#   'back',
#   'direction',
#   'pleasure',
#   '_établissement_.',
#   '_établissement_',
#   'flesh.',
#   '_établissement_',
#   'cheeks,',
#   'chapeaux.',
#   'passage,',
#   'lowest',
#   'soft',
#   'direction',
#   '_établissement_,',
#   'world',
#   'grass-green',
#   'counterpane',
#   '_établissement_',
#   'palace',
#   'palace',
#   'room',
#   'early',
#   'room',
#   'passage',
#   'heavenly',
#   'future,',
#   'hall,',
#   'world',
#   'world.',
#   'year',
#   'south',
#   'county',
#   'world',
#   'morning?',
#   'wide',
#   'cowld',
#   'dripping,',
#   'most',
#   'wide',
#   'face."',
#   'whole',
#   'garden,',
#   'bough',
#   'middle.',
#   'sky,',
#   'wide',
#   'house.',
#   'direction',
#   'sun',
#   'world',
#   'end',
#   'queer',
#   'evening,',
#   'world--nobler',
#   'direction',
#   'Desmond',
#   'huge',
#   'heart',
#   'midst',
#   'Desmond',
#   'least',
#   'most'],
#  'the County': ['Kerry.', 'of'],
#  'County Kerry.': ["Marguerite's"],
#  "Kerry. Marguerite's": ['father'],
#  "Marguerite's father": ['was'],
#  'father was': ['a', 'Comte'],
#  'was a': ['French',
#   'totally',
#   'very',
#   'Desmond,',
#   'God-fearing',
#   'delightful',
#   'very',
#   'bitter,',
#   'typical',
#   'custom',
#   'broken',
#   'big',
#   'rustling',
#   'young',
#   'very',
#   'look',
#   'wicked',
#   'babe',
#   'good',
#   'babby',
#   'most',
#   'loud,',
#   'Yorkshire',
#   'Paul',
#   'day',
#   'sort',
#   'likeness',
#   'flush',
#   'boy',
#   'child',
#   'great',
#   'Comtesse,',
#   'wicked',
#   'chapeau,',
#   'week',
#   'quiet',
#   'school,"',
#   'wonderfully',
#   'shop,',
#   'fair,',
#   'laughing,',
#   'very',
#   'happy',
#   'little',
#   'hedge',
#   'figure',
#   'little',
#   'Protestant',
#   'long,',
#   'difficult',
#   'little',
#   'writing',
#   'deep',
#   'frock',
#   'light',
#   'man',
#   'thoroughbred',
#   'trifle',
#   'very',
#   'little',
#   'true',
#   'true',
#   'fly,',
#   'black',
#   'very',
#   'huge',
#   'refreshing',
#   'girl',
#   'horrid',
#   'very',
#   'horrid',
#   'coal',
#   'favourite',
#   'nasty',
#   'man',
#   'calm',
#   'real',
#   'bit',
#   'bad',
#   'look',
#   'bad,',
#   'considerable',
#   'lady."',
#   'strange',
#   'little',
#   'certain',
#   'good',
#   'half-holiday,',
#   'green',
#   'mild',
#   'trifle',
#   'lovely',
#   'Desmond',
#   'deed',
#   'great',
#   'very',
#   'labourer',
#   'chair',
#   'time',
#   'solicitor'],
#  'a French': ['Comte,',
#   'Comtesse,',
#   'nobleman."',
#   'uncle',
#   '_petite_',
#   'school,'],
#  'French Comte,': ['whose'],
#  'Comte, whose': ['grandfather'],
#  'whose grandfather': ['had'],
#  'grandfather had': ['been'],
#  'had been': ['one',
#   'reduced,',
#   'dismissed.',
#   'born.',
#   'out',
#   'quite',
#   'put',
#   'so',
#   'acting',
#   'provided',
#   'stung',
#   'brought',
#   'further',
#   'flung',
#   'changed',
#   'bought',
#   'gazing',
#   'made',
#   'given',
#   'to',
#   'standing',
#   'helping',
#   'considering',
#   'too',
#   'in',
#   'brought',
#   'paid',
#   'told',
#   'finally',
#   'sold',
#   'born',
#   'well',
#   'provided.',
#   'secured'],
#  'been one': ['of'],
#  'one of': ['the',
#   'Uncle',
#   'the',
#   'the',
#   'the',
#   'the',
#   'his',
#   'the',
#   'his',
#   'the',
#   'her',
#   'her',
#   'your',
#   'those',
#   "Cook's",
#   "Margot's",
#   'her',
#   'the',
#   'the',
#   'the',
#   'the',
#   'her',
#   'her',
#   'the',
#   'the',
#   'her',
#   'thy',
#   'her',
#   'the',
#   'the',
#   'the',
#   'dark',
#   'the',
#   'those',
#   'them,',
#   'your',
#   'the',
#   'my',
#   '_those_',
#   'the',
#   'my',
#   'the',
#   'these',
#   'her',
#   'those',
#   'the',
#   'thine,',
#   'his',
#   'all',
#   'the'],
#  'the victims': ['of'],
#  'victims of': ['the'],
#  'the guillotine.': ['Little'],
#  'guillotine. Little': ['Marguerite'],
#  'Little Marguerite': ['lived'],
#  'Marguerite lived': ['with'],
#  'lived with': ['an', 'her', 'their'],
#  'with an': ['uncle,', 'effort.', 'excellent', "Irishman's", 'air'],
#  'an uncle,': ['who'],
#  'uncle, who': ['was'],
#  'was really': ['only',
#   'a',
#   'young,',
#   'engaged',
#   'sick.',
#   'ill.',
#   'called',
#   'a',
#   'fond'],
#  'really only': ['that'],
#  'only that': ['relation', 'he'],
#  'that relation': ['by'],
#  'relation by': ['marriage;'],
#  'by marriage;': ['his'],
#  'marriage; his': ['name'],
#  'his name': ['was'],
#  'name was': ['the', 'Harriet;', 'Louise', 'Kathleen'],
#  'was the': ['Reverend',
#   'Rev.',
#   'money',
#   'small',
#   'young',
#   'soul',
#   'spring',
#   'custom',
#   'signal',
#   'quietest',
#   'same',
#   'boy--there',
#   'last',
#   'eldest',
#   'only',
#   'aptest',
#   'master',
#   'extraordinary',
#   'torment',
#   'sort',
#   'French',
#   'sort',
#   'case.',
#   'angry',
#   'Comtesse,',
#   'well-known',
#   'lie,',
#   'dress',
#   'very',
#   'very',
#   'finish',
#   'sweet',
#   'ten',
#   'face',
#   'story;',
#   'only',
#   'one',
#   'only',
#   'good',
#   'case',
#   'spirit',
#   'little',
#   'chapeau',
#   'best',
#   'quick',
#   'reply.',
#   'mansion',
#   'doing',
#   'biggest',
#   'little',
#   'colour',
#   'palace',
#   'only',
#   'wet',
#   'most'],
#  'the Reverend': ['John', 'John.', 'John,'],
#  'Reverend John': ['Mansfield.'],
#  'John Mansfield.': ['He',
#   'You',
#   'He',
#   'Hannah',
#   '"I',
#   'His',
#   '"My',
#   '"He',
#   'The',
#   '"She\'s',
#   '"I',
#   '"I',
#   'The',
#   '"Ah,',
#   'There',
#   '"I',
#   'Now',
#   '"This'],
#  'Mansfield. He': ['had', 'did', 'turned'],
#  'He had': ['a',
#   'long',
#   'bushy',
#   'hoped',
#   'evidently',
#   'no',
#   'a',
#   'all',
#   'not',
#   'no',
#   'never',
#   'never',
#   'never',
#   'no',
#   'made',
#   'not',
#   'gone',
#   'lost',
#   'loved',
#   'never,'],
#  'had a': ['large',
#   'knack',
#   'certain',
#   'charming',
#   'portcullis,"',
#   'chat',
#   'strain',
#   'wicked',
#   'more',
#   'title,',
#   'long',
#   'goal',
#   'wonderfully',
#   'very',
#   'complete',
#   'heart',
#   'square',
#   'real',
#   'sort',
#   'tremendous',
#   'knack',
#   'shock',
#   'very',
#   'shrewd',
#   'glorious',
#   'horrible',
#   'rough',
#   'big',
#   'short',
#   'friend',
#   'strange',
#   'nature',
#   'sort',
#   'little',
#   'glow',
#   'terrible',
#   'minute',
#   'talk',
#   'tiny',
#   'twisted'],
#  'a large': ['living', 'town', '_magasin_,', 'scale,', 'mirror'],
#  'large living': ['in'],
#  'living in': ['a'],
#  'in a': ['large',
#   'great',
#   'week',
#   'deceitful',
#   'moment."',
#   'kind',
#   'poor',
#   "twinklin'.",
#   'bit',
#   'hopeless',
#   'fairly',
#   'big',
#   'very',
#   'pale',
#   'quiet',
#   'tone',
#   'very',
#   'bee',
#   'twinklin\'."',
#   'most',
#   '_more',
#   'girl',
#   'gaily',
#   'hurried',
#   'corner.',
#   'trifle',
#   'very',
#   'kind',
#   'corner.',
#   'twinkling.',
#   'shop.',
#   'shop?"',
#   'lively',
#   'shop."',
#   'pale',
#   'voice',
#   'sort',
#   'body',
#   'firm',
#   'very',
#   'hurried',
#   'shop."',
#   'state',
#   'swoon,',
#   'few',
#   'moment."',
#   'minute."',
#   'Reparation',
#   'sort',
#   'deep',
#   'hot',
#   'couple',
#   'couple',
#   'very',
#   'certain',
#   'corner',
#   'piece',
#   'packet.',
#   'puzzled',
#   'whirl',
#   'solemn,',
#   'hole.',
#   'cheerful',
#   'meek',
#   'sort',
#   'boat',
#   'bit',
#   'quarter',
#   'grave',
#   'minute',
#   'poorer',
#   'way',
#   'twink.',
#   'determined',
#   'shop.',
#   'gay,',
#   'harsh,',
#   'soft',
#   'sad',
#   'calm,',
#   'voice',
#   'unique',
#   'very',
#   'hurry',
#   'flash',
#   'mood',
#   'puzzled',
#   'certain',
#   'rambling,',
#   'great',
#   'moment,',
#   'good',
#   'wee',
#   'passion,',
#   'very',
#   'few',
#   'far',
#   'marvellous'],
#  'large town': ['about'],
#  'town about': ['fifty'],
#  'about fifty': ['miles'],
#  'fifty miles': ['from'],
#  'miles from': ['London,'],
#  'from London,': ['and'],
#  'London, and': ['he'],
#  'and he': ['adopted',
#   'knew,',
#   'began',
#   "didn't",
#   'knows',
#   "can't",
#   'did',
#   'walked',
#   'took',
#   'loves',
#   'thought',
#   'give',
#   'will',
#   'made',
#   "couldn't",
#   'promises',
#   'wants',
#   'will',
#   'married',
#   'is',
#   'with',
#   'knew',
#   'offered',
#   'was',
#   "can't",
#   'lifted',
#   'grew',
#   'forgave',
#   'stared',
#   'told',
#   'took',
#   "couldn't",
#   'riding',
#   'was',
#   'was',
#   'looked',
#   'wanted',
#   'was',
#   'would',
#   'steamed',
#   'lives',
#   'is',
#   'said',
#   'were',
#   'felt',
#   'ought',
#   '_never_',
#   'will',
#   'kept',
#   'must',
#   'will',
#   'would',
#   'clenched',
#   'has',
#   'did',
#   "isn't,",
#   'has',
#   'sat',
#   'did',
#   'the'],
#  'he adopted': ['Marguerite'],
#  'adopted Marguerite': ['shortly'],
#  'Marguerite shortly': ['after'],
#  'shortly after': ['the'],
#  'after the': ['death',
#   'bit',
#   'old,',
#   'Marquis',
#   'doctor',
#   'funeral,',
#   'first'],
#  'the death': ['of', 'of'],
#  'death of': ['her', '_mon_'],
#  'of her': ['parents.',
#   "father's",
#   "mother's",
#   'aunt,',
#   'good',
#   'small',
#   'up',
#   'grief',
#   'forever',
#   'dreams.',
#   'sobs,',
#   'so-called',
#   'ancestors,',
#   'childishness.',
#   'countrywomen,',
#   'dress,',
#   'old',
#   'all',
#   'own',
#   'husband,',
#   'whoops',
#   'screeches,',
#   'and',
#   'own',
#   'and',
#   'own,',
#   "husband's",
#   'soft',
#   'father,',
#   'mother.',
#   'much',
#   'choice.',
#   'day',
#   'days',
#   'manners,',
#   'dress.',
#   'own',
#   'schoolfellows.',
#   'bright',
#   'pretty',
#   'sky',
#   'numerous',
#   'car',
#   'life',
#   'sentence.',
#   'little',
#   'husband',
#   'three',
#   'ringing',
#   'French',
#   'appearance',
#   'ancestors.',
#   'departure',
#   'slow',
#   'life,',
#   'this',
#   'pocket',
#   'gratitude',
#   'forever',
#   'to',
#   'berth,',
#   'narrow',
#   'meditations',
#   'scanty',
#   'head,',
#   'rides',
#   'joyous',
#   'or',
#   'name,',
#   'grandfather',
#   'unfailing',
#   'race.',
#   'beautiful,',
#   'little',
#   'race,',
#   'grandfather,',
#   '_belle_',
#   'teachers.',
#   "friends'",
#   'dearest',
#   'hair',
#   "father's",
#   'mind.',
#   'life.',
#   'at',
#   'uncles',
#   'task',
#   'presence,',
#   "grandfather's",
#   'own',
#   'master'],
#  'her parents.': ['This'],
#  'parents. This': ['tragedy'],
#  'This tragedy': ['happened'],
#  'tragedy happened': ['when'],
#  'happened when': ['she'],
#  'when she': ['was',
#   'was',
#   'ventured',
#   "can't",
#   'lands,',
#   'parted',
#   'offered',
#   'was',
#   'awoke',
#   'was',
#   'was',
#   'was',
#   'was',
#   'encountered',
#   'was',
#   'had',
#   'gets',
#   'said',
#   'might',
#   'attempted',
#   'saw',
#   'swept',
#   'dropped',
#   'might',
#   'heard',
#   'did',
#   'unexpectedly',
#   'ran',
#   'talked',
#   'put',
#   'was',
#   'was',
#   'was',
#   'had',
#   'would',
#   'was',
#   'might',
#   'had',
#   'appeared',
#   'hinted',
#   'does',
#   'came'],
#  'she was': ['very',
#   'eleven',
#   'telling',
#   'awakened',
#   'accustomed',
#   'in',
#   'only',
#   'at',
#   'a',
#   'sleeping',
#   'quite',
#   'so',
#   'really',
#   'not',
#   'to',
#   'taunting',
#   'a',
#   'put',
#   'fair',
#   'a',
#   'in',
#   'barely',
#   'too',
#   'beautiful',
#   'to',
#   'fully',
#   'intensely',
#   'to',
#   'a',
#   'indeed',
#   'told.',
#   'expected',
#   'to',
#   'not',
#   'quite',
#   'dressed',
#   'met',
#   'not',
#   'determined',
#   'the',
#   'more',
#   'stung',
#   'stung.',
#   'going',
#   'a',
#   'nothing',
#   'a',
#   'working',
#   'going',
#   'with',
#   'coming',
#   'not',
#   'with',
#   'not',
#   'sitting',
#   'part',
#   'indeed',
#   'the',
#   'soon',
#   'at',
#   'a',
#   'quite',
#   'quite',
#   'not',
#   'a',
#   'likely',
#   'one',
#   'scampering',
#   'surrounded',
#   'incapable',
#   'no',
#   'making',
#   'a',
#   'wicked',
#   'on',
#   'going',
#   'going',
#   'only',
#   'thankful',
#   'really',
#   'attended',
#   'not',
#   'strangely',
#   'kind,',
#   'the',
#   'all',
#   'like',
#   'a',
#   'not',
#   'hurt',
#   'one',
#   'to',
#   'never',
#   'never',
#   'a',
#   'not',
#   'doing',
#   'called',
#   'learning',
#   'determined',
#   'doing',
#   'to',
#   'busy',
#   'doing',
#   'only',
#   'good-natured',
#   'not',
#   'so',
#   'really',
#   'in',
#   'not',
#   'a',
#   'indisposed',
#   '_la',
#   'a',
#   'born',
#   'arrested',
#   'her',
#   'old',
#   'my',
#   'nothing',
#   'determined',
#   'happy'],
#  'was very': ['young,',
#   'plain,',
#   'long',
#   'nice,',
#   'large',
#   'busy.',
#   'reliable.',
#   'awful',
#   'sorry',
#   'white.',
#   'pretty',
#   'perfect.',
#   'happy--his',
#   'grave.',
#   'grave',
#   'fond',
#   'uncommon'],
#  'very young,': ['almost', 'Aunt', 'Aunt', 'too,'],
#  'young, almost': ['a'],
#  'almost a': ['baby.', 'wicked'],
#  'a baby.': ['She'],
#  'baby. She': ['did', 'hated'],
#  'She did': ['not',
#   'not',
#   'manage',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'see,',
#   'not',
#   'not'],
#  'did not': ['in',
#   'like',
#   'love',
#   'dare',
#   'even',
#   'know',
#   'care',
#   'see',
#   'want',
#   'see--being',
#   'give',
#   'much',
#   'fail',
#   'appear.',
#   'look',
#   'take',
#   'know',
#   'matter',
#   'ache',
#   'think',
#   'go',
#   'wish',
#   'know',
#   'notice',
#   'once',
#   'believe',
#   'mind',
#   'gossoons',
#   'want',
#   'like',
#   'want',
#   'care',
#   'go',
#   'guess',
#   'do',
#   'stir.',
#   'see',
#   'look',
#   'know',
#   'object',
#   'trouble',
#   'conceal',
#   'attempt',
#   'wish',
#   'reply.',
#   'believe',
#   'come',
#   'wish',
#   'go',
#   'in',
#   'really',
#   'care',
#   'dare',
#   'feel',
#   'attempt',
#   'agree',
#   'take',
#   'mind',
#   'trouble',
#   'even',
#   'want',
#   'seem',
#   'keep',
#   'in',
#   'know',
#   'mean',
#   'mind',
#   'know',
#   'know',
#   'dare',
#   'cry.',
#   'look',
#   'believe',
#   'leave',
#   'want',
#   'know',
#   'find',
#   'appear',
#   'attempt',
#   'stop',
#   'see',
#   'usually',
#   'generally',
#   'give',
#   'Samuel',
#   'in',
#   'understand,'],
#  'not in': ['the', 'the', 'the', 'the', 'the', 'the', 'the'],
#  'the least': ['remember',
#   'like',
#   'for',
#   'like',
#   'notice.',
#   'disturbed',
#   'idea',
#   'disturbing',
#   'of',
#   'whether',
#   'inclined',
#   'admire',
#   'like',
#   'what',
#   'notice.',
#   'compete',
#   'mind',
#   'of',
#   'notice',
#   'understand,'],
#  'least remember': ['her'],
#  'remember her': ['father,', 'existence.', 'mother,'],
#  'her father,': ['whose', 'too.', 'very', 'whose'],
#  'father, whose': ['dancing', 'restaurant'],
#  'whose dancing': ['black'],
#  'dancing black': ['eyes'],
#  'black eyes': ['and',
#   'twinkling',
#   'were',
#   'entered.',
#   'fixed',
#   'fixed',
#   'with',
#   'into',
#   'of',
#   'and',
#   'full',
#   'seemed',
#   'were',
#   'shone,',
#   'had',
#   'to'],
#  'eyes and': ['merry',
#   'slowly',
#   'tried',
#   'in',
#   'fixing',
#   'it',
#   'looked',
#   'his',
#   'I',
#   'white'],
#  'and merry': ['ways', 'of'],
#  'merry ways': ['had'],
#  'ways had': ['endeared'],
#  'had endeared': ['him'],
#  'endeared him': ['to'],
#  'him to': ['all',
#   'look',
#   'sit',
#   'hoist',
#   'be',
#   'see',
#   'think',
#   'his',
#   'himself',
#   'death.',
#   'train',
#   'Mallow',
#   'you,"',
#   'say',
#   'think',
#   'love',
#   'know',
#   'tell',
#   'me?"',
#   'rise.',
#   'say'],
#  'to all': ['who', 'this'],
#  'all who': ['knew'],
#  'who knew': ['him.', 'him', 'the'],
#  'knew him.': ['Nor'],
#  'him. Nor': ['did'],
#  'Nor did': ['she'],
#  'did she': ['recall', 'provide', 'make', 'suspect', 'care', 'observe'],
#  'she recall': ['a'],
#  'recall a': ['single'],
#  'a single': ['fact', 'moment,"', 'point.'],
#  'single fact': ['with'],
#  'fact with': ['regard'],
#  'with regard': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'regard to': ['her',
#   'his',
#   'the',
#   'little',
#   'the',
#   'the',
#   'Tilly.',
#   'the',
#   'Matilda',
#   'his',
#   'her,'],
#  'to her': ['mother--one',
#   "uncle's",
#   'and',
#   'harsh',
#   'aunt.',
#   'breakfast;',
#   'nature',
#   'uncle.',
#   'station.',
#   'again."',
#   'or',
#   'scoldings,',
#   'French',
#   'grandfather.',
#   'French',
#   'own',
#   'aid.',
#   'little',
#   'grandpère',
#   'to-morrow',
#   'side.',
#   'and',
#   'in',
#   'friend',
#   'every',
#   'intense',
#   'hand.',
#   'ankles.',
#   'to-morrow',
#   'own',
#   'any',
#   'own',
#   'aunt,',
#   'almanac',
#   'as',
#   'grandpère.',
#   'a',
#   'that',
#   'school.',
#   'that',
#   'usual',
#   'grandfather',
#   'beautiful',
#   'back',
#   'English',
#   'for',
#   'own',
#   'intense',
#   'that',
#   'dreadful',
#   'young.',
#   'bedroom.',
#   'all',
#   'now,',
#   'that',
#   'father.',
#   'when',
#   'father',
#   'stepmother.',
#   "father's",
#   'now',
#   'as',
#   'friend,',
#   'accustomed',
#   'seat',
#   'grandfather,',
#   'and',
#   'word,',
#   'ideas,',
#   'own',
#   'by',
#   'summons.',
#   'feet.',
#   'servants',
#   'those',
#   'cheeks',
#   'room.',
#   'companion,',
#   'friends,',
#   'title',
#   'horror-stricken',
#   "husband's",
#   'through',
#   'own',
#   'first',
#   'own',
#   'to',
#   'window',
#   'the'],
#  'her mother--one': ['of'],
#  'mother--one of': ['those'],
#  'of those': ['famous',
#   'eyes',
#   'fine',
#   'quick',
#   'celebrated',
#   'wild',
#   'who',
#   'who'],
#  'those famous': ['Desmonds,'],
#  'famous Desmonds,': ['who'],
#  'Desmonds, who': ['had'],
#  'who had': ['joined',
#   'a',
#   'played',
#   'been',
#   'tried',
#   'sunk',
#   'done',
#   'spoken',
#   'really',
#   'come',
#   'the',
#   'the',
#   'been'],
#  'had joined': ['the'],
#  'joined the': ['rebels', 'child.'],
#  'the rebels': ['in'],
#  'rebels in': ['the'],
#  'the great': ['insurrection',
#   'kindnesses',
#   'hall',
#   'bare,',
#   'station',
#   'school',
#   'God',
#   'turf',
#   'front',
#   '_établissement_',
#   'hall,',
#   'turf',
#   '_établissement_.',
#   'school,',
#   'despair',
#   'wax'],
#  'great insurrection': ['of'],
#  'insurrection of': ["'97,"],
#  "of '97,": ['and'],
#  "'97, and": ['whose'],
#  'and whose': ['people', 'eyes', 'face'],
#  'whose people': ['still'],
#  'people still': ['lived'],
#  'still lived': ['and'],
#  'lived and': ['prospered'],
#  'and prospered': ['and'],
#  'prospered and': ['were'],
#  'and were': ['gay', 'there', 'called'],
#  'were gay': ['and'],
#  'gay and': ['merry', 'obliging.'],
#  'merry of': ['the'],
#  'the merry': ['on', 'things'],
#  'merry on': ['their'],
#  'on their': ['somewhat',
#   'bent',
#   'shoulders."',
#   'quest',
#   'faces.',
#   'journey',
#   'heads,',
#   'mission',
#   'cheeks.'],
#  'their somewhat': ['tattered'],
#  'somewhat tattered': ['and'],
#  'tattered and': ['worn-out'],
#  'and worn-out': ['country'],
#  'worn-out country': ['estate.'],
#  'country estate.': ['Marguerite'],
#  'estate. Marguerite': ['adored'],
#  'Marguerite adored': ['"Uncle'],
#  'adored "Uncle': ['Jack,"'],
#  '"Uncle Jack,"': ['as'],
#  'Jack," as': ['she'],
#  'as she': ['called',
#   'was,',
#   'listened',
#   'snuggled',
#   'alone',
#   'spoke.',
#   'might,',
#   'did',
#   'likes.',
#   'is',
#   'could,',
#   'spoke',
#   'could',
#   'expressed',
#   'was',
#   'called',
#   'called',
#   'spoke.',
#   'loved',
#   'went.',
#   'could',
#   'expressed',
#   'watched',
#   'replied',
#   'was',
#   'bade',
#   'liked,',
#   'hurried',
#   'saw',
#   'was',
#   'could,',
#   'is',
#   'returned',
#   'sold',
#   'spoke',
#   'does,',
#   'watched'],
#  'she called': ['her', '"last', 'the', 'him', 'by', 'the'],
#  'called her': ['supposed', 'a', 'into'],
#  'her supposed': ['uncle.', '_dot_,'],
#  'supposed uncle.': ['She'],
#  'uncle. She': ['had', 'sat'],
#  'She had': ['a',
#   'managed,',
#   'a',
#   'arranged',
#   'begun',
#   'no',
#   'been',
#   'the',
#   'by',
#   'from',
#   'little',
#   'a',
#   'a',
#   'great',
#   'become',
#   'a',
#   'an',
#   'light',
#   'told',
#   'a',
#   'just',
#   'an',
#   'only',
#   'met',
#   'enjoyed',
#   'read',
#   'money',
#   'partaken',
#   'seen',
#   'bought',
#   'the',
#   'a',
#   'gone',
#   'much',
#   'received',
#   'a',
#   'seen',
#   'never',
#   'only',
#   'to'],
#  'a knack': ['of', 'of'],
#  'knack of': ['turning', 'picking'],
#  'of turning': ['this'],
#  'turning this': ['grave'],
#  'this grave': ['and'],
#  'grave and': ['esteemed', 'dark,', 'lovely', 'distrait.', 'very'],
#  'and esteemed': ['gentleman,'],
#  'esteemed gentleman,': ['so'],
#  'gentleman, so': ['to'],
#  'so to': ['speak,', 'speak."'],
#  'to speak,': ['round'],
#  'speak, round': ['her'],
#  'round her': ['little', 'to', 'shoulders', 'and', 'neck;', 'slim'],
#  'her little': ['finger.',
#   'arms',
#   'pocket.',
#   'heart,"',
#   'brown',
#   'girl,',
#   'face',
#   'cool',
#   'wardrobe.',
#   'child',
#   'cot',
#   'pricked',
#   'nose.',
#   'cabin.',
#   'self,',
#   'self."',
#   'fists.',
#   'cap',
#   'brown',
#   'Margot.',
#   'basket',
#   'basket.',
#   'mind;',
#   'heart."'],
#  'little finger.': ['It'],
#  'finger. It': ['was'],
#  'It was': ['the',
#   'easy',
#   'that',
#   'the',
#   'of',
#   'going',
#   'a',
#   'two',
#   'in',
#   'just',
#   'Malachi',
#   'because',
#   'trimmed',
#   'tried',
#   'pronounced',
#   'quite',
#   'in',
#   'a',
#   'now',
#   'me',
#   'lovely',
#   'a',
#   'a',
#   'amazing',
#   'no',
#   'a',
#   'a',
#   'very',
#   'the',
#   'a',
#   'proved',
#   'wrong',
#   'never',
#   'not',
#   'strong,',
#   'called',
#   'true,',
#   'wonderful',
#   'like',
#   'urgent,',
#   'the',
#   'just',
#   'rapid,',
#   'only',
#   'an',
#   'so',
#   'without',
#   'a',
#   'close',
#   'Margot'],
#  'the Rev.': ['John',
#   'John',
#   'John',
#   'John',
#   'John',
#   'John',
#   'John',
#   'John',
#   'John',
#   'John',
#   'Samuel',
#   'John'],
#  'Rev. John': ['and',
#   'Mansfield',
#   'Mansfield',
#   'without',
#   'looked',
#   'Mansfield',
#   'Mansfield,',
#   'Mansfield.',
#   'Mansfield.',
#   'Mansfield.',
#   'Mansfield.',
#   'Mansfield'],
#  'John and': ['his', 'of', 'the'],
#  'and his': ['wife',
#   'complexion',
#   'retainers.',
#   'tribe.',
#   'son,',
#   'wife',
#   'Ninon',
#   'beard',
#   'eyes',
#   'great',
#   'gravity',
#   'calm,',
#   'thick',
#   'beautiful',
#   'mouth',
#   'head'],
#  'his wife': ['Priscilla', 'away.', 'Annie,', 'will'],
#  'wife Priscilla': ['who'],
#  'Priscilla who': ['taught'],
#  'who taught': ['little'],
#  'taught little': ['Marguerite'],
#  'little Marguerite': ['all', 'St.', 'told'],
#  'Marguerite all': ['she'],
#  'all she': ['knew.', 'knows,'],
#  'she knew.': ['She'],
#  'knew. She': ['adored'],
#  'She adored': ['her', '_mon_'],
#  'adored her': ['uncle;'],
#  'her uncle;': ['she'],
#  'uncle; she': ['did'],
#  'she did': ['not',
#   'not',
#   'feel',
#   'so.',
#   'most',
#   'not',
#   'so,',
#   'before',
#   'not',
#   'not',
#   'wrong,"',
#   'that',
#   'not',
#   'not',
#   'get',
#   'not.',
#   'go,',
#   'on',
#   'comprehend,',
#   'not',
#   'not'],
#  'not like': ['his', 'Hébé.', 'me', 'The', 'a', 'his', 'the', 'Malachi'],
#  'like his': ['wife.', 'father', 'training'],
#  'his wife.': ['A', 'She', 'The', '"All', '"Oh,'],
#  'wife. A': ['sterner'],
#  'A sterner': ['or'],
#  'sterner or': ['stricter'],
#  'or stricter': ['woman'],
#  'stricter woman': ['than'],
#  'woman than': ['Priscilla'],
#  'than Priscilla': ['Mansfield'],
#  'Priscilla Mansfield': ['it'],
#  'Mansfield it': ['would'],
#  'it would': ['be', 'come', 'fatigue', 'soon', 'be', 'be', 'be', 'fetch'],
#  'would be': ['hard',
#   'nothing',
#   'absent',
#   'nothing',
#   'sorry',
#   'quite',
#   'returning',
#   'good',
#   'to',
#   'safer',
#   'her',
#   'awful',
#   'one',
#   'very,',
#   'sorry.',
#   'a',
#   'petted',
#   'furious',
#   'contrary',
#   'disliked',
#   'with',
#   'dismissed,',
#   'fatal.',
#   'the',
#   'right',
#   'complete',
#   'in',
#   'his',
#   'at'],
#  'be hard': ['to'],
#  'hard to': ['find.', 'see'],
#  'to find.': ['Her'],
#  'find. Her': ['husband,'],
#  'Her husband,': ['it'],
#  'husband, it': ['is'],
#  'it is': ['true,',
#   'true,',
#   'a',
#   'chock',
#   'wrong',
#   'all',
#   'true,',
#   'the',
#   'all',
#   'a',
#   '_lovely_',
#   'Sunday,',
#   'a',
#   'of',
#   'to',
#   'of',
#   'a',
#   'a',
#   'acquired',
#   'red',
#   'of',
#   'marvellous!',
#   'the',
#   'clean,',
#   'white.',
#   'done!"',
#   'one',
#   'quite',
#   'now',
#   'a',
#   'not',
#   'broken,',
#   'broken!',
#   'hopeless--quite',
#   'not',
#   'pulp!"',
#   'like',
#   'time',
#   'fair',
#   'like',
#   'silly,"',
#   'on',
#   'put',
#   'of',
#   'less',
#   'very',
#   'a',
#   'in',
#   'so,',
#   'really',
#   'a',
#   'the',
#   'golden',
#   'true,',
#   '_supposed_',
#   'true,',
#   'not',
#   'sorrow',
#   'necessary,',
#   'what',
#   'joyful',
#   'the',
#   'wrong."'],
#  'is true,': ['considered', 'but', 'all', 'a', 'of', 'what', 'many'],
#  'true, considered': ['her'],
#  'considered her': ['admirable,'],
#  'her admirable,': ['for'],
#  'admirable, for': ['she'],
#  'for she': ['discovered',
#   'is',
#   'is',
#   'may',
#   'came',
#   'was',
#   'could',
#   'is',
#   'had',
#   'has',
#   'inherited',
#   'loves'],
#  'she discovered': ['whenever', 'in'],
#  'discovered whenever': ['his'],
#  'whenever his': ['parishioners'],
#  'his parishioners': ['tried'],
#  'parishioners tried': ['to'],
#  'tried to': ['impose',
#   'do',
#   'rule',
#   'befriend',
#   'be',
#   'give',
#   'escape,',
#   'soothe',
#   'tell',
#   'smooth',
#   'find'],
#  'to impose': ['upon'],
#  'impose upon': ['him,'],
#  'upon him,': ['and'],
#  'him, and': ['kept',
#   'he',
#   'we',
#   "there's",
#   'he',
#   'each',
#   'when',
#   'in',
#   'he',
#   'surely',
#   'he'],
#  'and kept': ['the', 'on', 'her', 'him', 'talking', 'a', 'her', 'looking'],
# ...
#  'otherwise--but little': ['Margot'],
#  'Margot did': ['not',
#   'so.',
#   'what',
#   'not',
#   'sleep',
#   'not',
#   'not',
#   'not',
#   'awake',
#   'not',
#   'not',
#   'not',
#   'not'],
#  'not dare': ['to', 'to', 'to'],
#  'dare to': ['think', 'insult', 'speak', 'despise', 'lose'],
#  'to think': ['of', 'about', 'so', 'he', 'that', 'of', 'of', 'me', 'how'],
#  'think of': ['otherwise.',
#   'one',
#   'her',
#   'her,"',
#   'the',
#   'the',
#   'Comtes',
#   'anyone',
#   'it',
#   'nothing',
#   'her.',
#   'herself.',
#   'our',
#   'her',
#   'the',
#   'the'],
#  'of otherwise.': ['Was'],
#  'otherwise. Was': ['she'],
#  'Was she': ['not'],
#  'she not': ['herself',
#   'the',
#   'the',
#   'been',
#   'to',
#   'providing',
#   'help',
#   'load',
#   'with',
#   'remembered'],
#  'not herself': ['a'],
#  'herself a': ['mixture', 'princess,'],
#  'a mixture': ['of'],
#  'mixture of': ['both'],
#  'of both': ['Irish'],
#  'both Irish': ['and'],
#  'Irish and': ['French,'],
#  'and French,': ['and'],
#  'French, and': ['could'],
#  'and could': ['there', 'not', 'pay', 'not', 'not', 'not'],
#  'could there': ['be', 'be'],
#  'there be': ['any', 'a', 'revenge?"'],
#  'be any': ['two', 'the', 'longer,"'],
#  'any two': ['nations'],
#  'two nations': ['more'],
#  'nations more': ['sure'],
#  'more sure': ['to'],
#  'sure to': ['produce', 'keep'],
#  'to produce': ['a'],
#  'produce a': ['child'],
#  'a child': ['like', 'and', 'and', 'of', 'who', 'of'],
#  'child like': ['Margot--a'],
#  'like Margot--a': ['child'],
#  'Margot--a child': ['full'],
#  'child full': ['of'],
#  'full of': ['life',
#   'events',
#   'the',
#   'curl',
#   'sense.',
#   'admiration.',
#   'Irish',
#   'holes',
#   'years,',
#   'smiles',
#   'pleasure.',
#   'comfort,',
#   'things',
#   'love,',
#   'that',
#   'a',
#   'interest',
#   'Roses--oh,',
#   'untold',
#   'the'],
#  'of life': ['and', 'that'],
#  'life and': ['fearlessness,', 'I', 'prosperity.', 'joy'],
#  'and fearlessness,': ['of'],
#  'fearlessness, of': ['fun'],
#  'of fun': ['and', 'we', 'in'],
#  'fun and': ['daring?'],
#  'and daring?': ['She'],
#  'daring? She': ['longed'],
#  'She longed': ['inexpressibly', 'to', 'inexpressibly', 'beyond'],
#  'longed inexpressibly': ['for', 'for'],
#  'inexpressibly for': ['companionship,', 'Margot'],
#  'for companionship,': ['but'],
#  'companionship, but': ['young'],
#  'but young': ['people'],
#  'young people': ['were', 'or', 'to'],
#  'people were': ['not', 'talked', 'so'],
#  'not permitted': ['to'],
#  'permitted to': ['visit'],
#  'to visit': ['at', 'her', 'her', 'my', 'the', 'me', 'their', 'M.'],
#  'visit at': ['the'],
#  'at the': ['Rectory.',
#   'Rectory',
#   'quaint',
#   'restaurant',
#   'rapid',
#   'handwriting',
#   'pretty',
#   'gate.',
#   'side',
#   'dawn',
#   'old',
#   'figures',
#   'gate."',
#   'back',
#   'first',
#   'present',
#   'present',
#   'thought,',
#   'thought',
#   'thought',
#   'French',
#   'same',
#   'tiny',
#   'Princesse',
#   'school',
#   'school',
#   '_établissement_,',
#   'ancient',
#   'little',
#   '_établissement_',
#   'school',
#   'school',
#   'pretty,',
#   'château,',
#   'school',
#   'end',
#   "doctor's",
#   'confusion',
#   'little',
#   'thought',
#   'highest',
#   'side',
#   'school',
#   'station',
#   'thought',
#   'little',
#   'station',
#   'gate',
#   'dawn',
#   'little',
#   'happy',
#   'thought',
#   'mid-day',
#   'door.',
#   'back',
#   'girl.',
#   'school.',
#   'creature',
#   'table.',
#   'long',
#   'head',
#   'present',
#   'truth',
#   'man;',
#   'gold',
#   'house',
#   'broken-down',
#   'doorway',
#   'door.',
#   'other.',
#   'school',
#   '_établissement_',
#   'Château',
#   '_établissement_',
#   'end',
#   "pushkeen's",
#   'other',
#   'side',
#   'grass-green',
#   'shape,',
#   'invincible',
#   'Boulevard',
#   'château',
#   'very',
#   'gates',
#   'lodge.',
#   'queer-looking',
#   'lodge',
#   'chapeau',
#   'beautiful',
#   'château',
#   'thought',
#   '_Cabinet',
#   'Château',
#   '_Cabinet',
#   'hour',
#   'very',
#   '_établissement_.',
#   'heart."',
#   'present',
#   'clock',
#   'door.',
#   '_établissement_',
#   '_établissement_',
#   'head',
#   'feet.',
#   'thought',
#   'way',
#   'Romney.',
#   'little',
#   'picture.',
#   'back',
#   'hand.',
#   'door.',
#   'pretty',
#   'most,"',
#   'wedding',
#   'head',
#   'child.'],
#  'the Rectory.': ['She', 'It'],
#  'Rectory. She': ['dreamed'],
#  'She dreamed': ['long'],
#  'dreamed long': ['dreams'],
#  'long dreams': ['of'],
#  'dreams of': ['her'],
#  "her father's": ['people',
#   'and',
#   'presence.',
#   'death',
#   'face.',
#   'stern',
#   'station',
#   'large',
#   'and',
#   'cars'],
#  "father's people": ['in'],
#  'people in': ['the', 'the', 'Ireland', 'the'],
#  'the Château': ['St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.',
#   'St.'],
#  'Château St.': ['Juste,',
#   'Juste.',
#   'Juste.',
#   'Juste."',
#   'Juste,',
#   'Juste,',
#   'Juste',
#   'Juste.',
#   'Juste',
#   'Juste?',
#   'Juste."',
#   'Juste."',
#   'Juste.',
#   'Juste',
#   'Juste,'],
#  'St. Juste,': ['an',
#   'the',
#   'and',
#   'and',
#   'your',
#   'although',
#   'according',
#   '_mon_',
#   'they',
#   'and',
#   'does',
#   'but',
#   'and',
#   'he',
#   'wearing',
#   'which'],
#  'Juste, an': ['old'],
#  'an old': ['place',
#   'leather',
#   'friend.',
#   'tree!',
#   'man',
#   'man',
#   'man',
#   'woman',
#   'mare?',
#   'man',
#   'wound."'],
#  'old place': ['near', 'look', 'gone'],
#  'place near': ['Arles,'],
#  'near Arles,': ['in'],
#  'Arles, in': ['South'],
#  'in South': ['France,', 'France'],
#  'South France,': ['and'],
#  'France, and': ['of', 'nothing'],
#  'and of': ['her',
#   'his',
#   'enormous',
#   'a',
#   'what',
#   'what',
#   'learning',
#   'the',
#   'grand-dad',
#   'the',
#   'the',
#   "Tilly's",
#   'course',
#   'your',
#   '_mon',
#   'great',
#   'great',
#   'a',
#   'course',
#   'dear,',
#   'her'],
#  "mother's people": ['at'],
#  'people at': ['Desmondstown--an'],
#  'at Desmondstown--an': ['old'],
#  'Desmondstown--an old': ['estate'],
#  'old estate': ['gone'],
#  'estate gone': ['almost'],
#  'gone almost': ['to'],
#  'almost to': ['rack'],
#  'to rack': ['and', 'and', 'and'],
#  'rack and': ['ruin,', 'ruin', 'ruin,'],
#  'and ruin,': ['for', 'and'],
#  'ruin, for': ['where'],
#  'for where': ['was'],
#  'where was': ['the'],
#  'the money': ['to', 'go,', "I'll", 'was', 'goes', 'so'],
#  'money to': ['keep', 'go', 'buy', 'keep', 'supply', 'settle', 'give', 'get'],
#  'to keep': ['it',
#   'that',
#   'the',
#   'together.',
#   'her',
#   'it',
#   'themselves',
#   'her,',
#   'her.',
#   'her',
#   'her."',
#   'their',
#   'from',
#   'the',
#   'the',
#   'your',
#   'up',
#   'Aunt',
#   'back'],
#  'keep it': ['up?',
#   'in',
#   'dark--very',
#   'from',
#   'going--going--going,',
#   'dark',
#   'back',
#   'tight',
#   'tight',
#   'dark,'],
#  'it up?': ['Mr.'],
#  'up? Mr.': ['Mansfield'],
#  'Mr. Mansfield': ['was', 'into'],
#  'was well': ['aware', 'done,', 'acquainted'],
#  'well aware': ['of', 'of'],
#  'aware of': ['the', 'the'],
#  'the state': ['to', 'of'],
#  'state to': ['which'],
#  'to which': ['both'],
#  'which both': ['families'],
#  'both families': ['had', 'had'],
#  'families had': ['been', 'gone'],
#  'been reduced,': ['but'],
#  'reduced, but': ['when'],
#  'but when': ['his',
#   'she',
#   'I',
#   'we',
#   'Uncle',
#   'she',
#   'we',
#   'ye',
#   'it',
#   'he',
#   'Margot',
#   'you'],
#  'when his': ['little', 'description'],
#  'his little': ['darling,',
#   "darling's",
#   'kingdom',
#   'niece',
#   'Margot,',
#   'treasure,',
#   'angel',
#   'Ninon,',
#   'cabbage',
#   'grandchild.',
#   'granddaughter',
#   'Margot!',
#   'Margot',
#   'Margot.',
#   'old',
#   'granddaughter,',
#   'flicker'],
#  'little darling,': ['as'],
#  'darling, as': ['he'],
#  'as he': ['called',
#   'was,',
#   'said',
#   'thought',
#   'was',
#   'crossed',
#   'ought',
#   'was',
#   'expressed',
#   'would.',
#   'made',
#   'brought',
#   'opened',
#   'hears',
#   'called',
#   'could.',
#   'was',
#   'complained,',
#   'was'],
#  'he called': ['Margot,', 'his', 'her.', '_The'],
#  'called Margot,': ['liked'],
#  'Margot, liked': ['to'],
#  'liked to': ['talk', 'train,'],
#  'to talk': ['about',
#   'the',
#   'about',
#   '_against_',
#   'to',
#   'very',
#   'to',
#   'about',
#   'about'],
#  'talk about': ['her',
#   'there',
#   'your',
#   'Tilly,',
#   'pushkeen',
#   'anything',
#   'babies."'],
#  'about her': ["father's",
#   'in',
#   'French',
#   'to',
#   "niece's",
#   'and',
#   'and',
#   'at',
#   'there,"',
#   'little',
#   'every',
#   'supposed'],
#  "father's and": ["mother's", 'her'],
#  "and mother's": ['people,'],
#  "mother's people,": ['he'],
#  'people, he': ['invariably'],
#  'he invariably': ['encouraged'],
#  'invariably encouraged': ['her;'],
#  'encouraged her;': ['that'],
#  'her; that': ['is,'],
#  'that is,': ['provided', 'if', 'if'],
#  'is, provided': ['her'],
#  'provided her': ['aunt'],
#  'her aunt': ['was', 'love'],
#  'aunt was': ['not'],
#  'was not': ['present.',
#   'what',
#   'afraid',
#   'famous',
#   'in',
#   'to',
#   'nearly',
#   'obliged',
#   'the',
#   'very',
#   'going',
#   'at',
#   'to',
#   'an',
#   'what',
#   'quite',
#   'the',
#   'with',
#   'thoroughly',
#   'sure',
#   'yet',
#   'Margot.',
#   'going',
#   'allowed',
#   'behindhand',
#   'to',
#   'our',
#   'asleep.',
#   'to',
#   'M.',
#   'according',
#   'very',
#   'accustomed',
#   'too',
#   'there',
#   'to',
#   'the',
#   'true',
#   'far',
#   'accomplished.',
#   'there',
#   'the'],
#  'not present.': ['Mrs.'],
#  'present. Mrs.': ['Mansfield'],
#  'Mansfield snapped': ['up'],
#  'snapped up': ['the'],
#  'up the': ['child',
#   'thread.',
#   'hole',
#   'Latin',
#   'child',
#   'avenue.',
#   '_établissement_',
#   '_établissement_',
#   'highroad.',
#   'saddle,',
#   'rest',
#   'companion',
#   '_établissement_,',
#   'perfectly',
#   'avenue',
#   '_dot_,',
#   'cause',
#   'baby',
#   'place'],
#  'the child': ['whenever',
#   'pleaded',
#   'that',
#   'and',
#   'was',
#   'and',
#   'to',
#   'wanted',
#   'is',
#   'mean',
#   'into',
#   'when',
#   'from',
#   'from',
#   'belongs',
#   'pined',
#   'when',
#   'that',
#   'go',
#   'of',
#   'without',
#   'whom',
#   'has',
#   'of',
#   'altogether,',
#   'on',
#   'and',
#   'should',
#   'with',
#   'the',
#   'who',
#   'for',
#   'to',
#   'of',
#   'very',
#   'of',
#   'was',
#   'and',
#   'from',
#   'betrayed'],
#  'child whenever': ['her'],
#  'whenever her': ['own'],
#  'her own': ['people',
#   'portion.',
#   'grandparents',
#   'uncles',
#   'people',
#   'accord',
#   'true',
#   'people,',
#   'goodly',
#   'accord',
#   'stores',
#   'ideas,',
#   'mind',
#   'immediate',
#   'ideas."',
#   'small',
#   'room',
#   'taste.',
#   'words,',
#   '_dot_,',
#   'sweet',
#   'room,',
#   'object',
#   'poor',
#   'mind',
#   'way.',
#   'account,',
#   'worldly',
#   'little',
#   'clever',
#   'wonderful',
#   'eyes,',
#   'purposes',
#   'ideas.',
#   'father',
#   'snug',
#   'cosy',
#   'little',
#   'determination',
#   'way.'],
#  'own people': ['were', 'for'],
#  'were talked': ['of.'],
#  'talked of.': ['She'],
#  'of. She': ['assured'],
#  'She assured': ['her'],
#  'assured her': ['that', 'that', 'that'],
#  'her that': ['both',
#   'all',
#   'the',
#   'she',
#   'she',
#   'a',
#   'she',
#   'she',
#   'she',
#   'she',
#   'the',
#   'he',
#   'she',
#   'she',
#   'she',
#   'they',
#   'the',
#   'all'],
#  'that both': ['families'],
#  'had gone': ['to',
#   'to',
#   'as',
#   'into',
#   'into',
#   'to',
#   'by,',
#   'herself',
#   'that',
#   'to',
#   'that'],
#  'gone to': ['the', 'ruin,', 'rack', 'acquaint', 'the'],
#  'the dogs': ['and'],
#  'dogs and': ['did'],
#  'and did': ['not', 'her', 'not', 'not', 'not', 'not'],
#  'not even': ['remember', 'send', 'wait'],
#  'even remember': ['her'],
#  'her existence.': ['"You'],
#  'existence. "You': ['ought'],
#  '"You ought': ['to'],
#  'ought to': ['be',
#   'be',
#   'be',
#   'have',
#   'be',
#   'be."',
#   'go',
#   'go',
#   'wire',
#   'be',
#   'know,"',
#   'happen',
#   'tell',
#   'present'],
#  'to be': ['very',
#   'one.',
#   'an',
#   'sure."',
#   'sure,',
#   'sure,',
#   'concealed',
#   'good',
#   'a',
#   'wicked',
#   'wicked,',
#   'sure,',
#   "'shamed",
#   'mighty',
#   'proud',
#   'quite',
#   'sure',
#   'mentioned',
#   'ashamed',
#   'expected."',
#   'called',
#   'got',
#   'with',
#   'sure',
#   'petted',
#   'sure,"',
#   'sure',
#   'thinking',
#   'offended,',
#   'very',
#   'broken',
#   'a',
#   'as',
#   'sure',
#   '"hail-fellow-well-met"',
#   'seen',
#   'sure',
#   'done.',
#   'niece',
#   'sure',
#   'sartin',
#   'mentioned',
#   'sure,',
#   'sure,',
#   'sure,',
#   'one',
#   'rid',
#   'sure,"',
#   'said."',
#   'said,',
#   'sure,',
#   'with',
#   'fulfilled,',
#   'seen',
#   'unfair.',
#   'sure,',
#   'heard',
#   'said',
#   'the',
#   'near',
#   'able',
#   'a',
#   'seen.',
#   'a',
#   'your',
#   'suited',
#   'good.',
#   'done--Uncle',
#   'under',
#   'killed',
#   'a',
#   'close',
#   'to',
#   'seen,',
#   'getting',
#   'sure,',
#   'compared',
#   'a',
#   'put',
#   'first',
#   'worried.',
#   'sure.',
#   'sure,',
#   'sure,',
#   'sure,',
#   'sure?"',
#   'sure',
#   'sure,',
#   'very',
#   'sure,',
#   'acquainted',
#   'sure.',
#   'going',
#   'on',
#   'angry,',
#   'kind.',
#   'seen',
#   'considered',
#   'sure,',
#   'sure,',
#   'a',
#   'content.',
#   'a',
#   'out',
#   'taught',
#   'enlightened.',
#   'sure,"',
#   '_vite_.',
#   'proud',
#   'there',
#   'kept',
#   'instructed',
#   'present',
#   'vain,',
#   'recognised,',
#   'alone',
#   'opened',
#   'her',
#   'married,',
#   'sure,',
#   'married',
#   'married.',
#   'sure."',
#   'unhappy."',
#   'sure,',
#   'good',
#   'happy."',
#   'gone',
#   'held',
#   'sure,',
#   'a'],
#  'be very': ['thankful',
#   'careful."',
#   'careful',
#   'good',
#   'attentive',
#   'busy',
#   'soon,',
#   'nice,'],
#  'very thankful': ['to'],
#  'thankful to': ['have', 'be'],
#  'to have': ['an',
#   'ye',
#   'lost',
#   'mercy',
#   'got',
#   'a',
#   'been',
#   'her',
#   'recourse',
#   'a',
#   'a',
#   'the',
#   'the',
#   'not',
#   'you',
#   'a',
#   'my',
#   'tea',
#   'thee',
#   'the',
#   '_la',
#   'a',
#   'no',
#   'one',
#   'a',
#   'a',
#   'his',
#   'stirred',
#   'his',
#   'her',
#   'the',
#   'her',
#   'their',
#   'their',
#   'them,',
#   'a',
#   'changed',
#   'a',
#   'babies."'],
#  'have an': ['uncle', 'hour'],
#  'an uncle': ['and'],
#  'uncle and': ['aunt', 'my'],
#  'and aunt': ['like'],
#  'aunt like': ['myself', 'that,"'],
#  'like myself': ['and'],
#  'myself and': ['your', "I'll", 'see'],
#  'and your': ['Uncle',
#   'uncles.',
#   'own',
#   'habit',
#   'shoulders.',
#   'low-down',
#   'friend',
#   'granddad,"',
#   'little',
#   "_'mendous_",
#   'own',
#   'travelling.'],
#  'your Uncle': ['John,"'],
#  'Uncle John,"': ['said'],
#  'John," said': ['the', 'the', 'Mrs.'],
#  'said the': ['good',
#   'Rector,',
#   'Rector.',
#   'Reverend',
#   'Irishman,',
#   'youngest',
#   'old',
#   'son.',
#   'farmer,',
#   'farmer.',
#   'other',
#   'future',
#   'Comte,',
#   'Rev.',
#   'Comte;',
#   'present',
#   'old',
#   'old',
#   'child.',
#   'Comtesse.',
#   'American.',
#   'red-faced',
#   'child,',
#   'old',
#   'Comtesse,',
#   'bees',
#   'Comtesse.',
#   'poor',
#   'doctor.',
#   'old',
#   'elderly',
#   'old',
#   'old',
#   'clergyman,',
#   'child.',
#   'old',
#   'old',
#   'old',
#   'stewardess,',
#   'coal-merchant.',
#   'coal-merchant.',
#   'coal-merchant.',
#   'pushkeen.',
#   'Comtesse.',
#   'girl',
#   'Comte',
#   'old',
#   'Comte.',
#   'Comte,',
#   'Comte.',
#   'Comte.',
#   'ladies,',
#   'Marquise',
#   'old',
#   'astonished',
#   'poor',
#   'little',
#   'doctor.',
#   'poor',
#   'Comte,',
#   'old',
#   'old',
#   'doctor,',
#   'notary.',
#   'almost',
#   'old',
#   'first'],
#  'the good': ['woman.',
#   'man',
#   'and',
#   'man',
#   'lady.',
#   'babe',
#   'face',
#   'Desmond',
#   'woman,',
#   'folks',
#   'of',
#   'God',
#   'of',
#   'God;'],
#  'good woman.': ['"If', "She's"],
#  'woman. "If': ['my'],
#  '"If my': ['John'],
#  'my John': ['was'],
#  'John was': ['not', 'always'],
#  'not what': ['he', 'she', 'it'],
#  'what he': ['is,',
#   'be',
#   'says',
#   'knew',
#   'can',
#   'called',
#   'meant',
#   'thinks,',
#   'thinks,'],
#  'he is,': ['you'],
#  'is, you': ['would'],
#  'you would': ['be', 'put', 'have'],
#  'be nothing': ['more', 'but'],
#  'nothing more': ['nor', 'to', 'in', 'to'],
#  'more nor': ['less'],
#  'nor less': ['than'],
#  'less than': ['a', '£20', 'of', 'the', 'a', 'nothing.'],
#  'than a': ['miserable',
#   'chick',
#   'school.',
#   'fortnight',
#   'week."',
#   'figurehead.'],
#  'a miserable': ['little'],
#  'miserable little': ['beggar.', 'secret'],
#  'little beggar.': ['See'],
#  'beggar. See': ['that'],
#  'See that': ['you'],
#  'that you': ['obey',
#   'gave',
#   'have',
#   'must',
#   'want',
#   'are',
#   'walk',
#   'were',
#   'know',
#   'are',
#   'have',
#   'may',
#   'could',
#   'are',
#   'should',
#   'may',
#   'wish',
#   'and',
#   'will',
#   'will',
#   'are',
#   'kept',
#   'are',
#   'were',
#   'came',
#   'and',
#   'are',
#   'and',
#   'need',
#   'can'],
#  'you obey': ['us'],
#  'obey us': ['both'],
#  'us both': ['and'],
#  'both and': ['do'],
#  'and do': ['your', 'something', 'his', 'the', 'not'],
#  'do your': ['best', 'lovely', 'duty'],
#  'your best': ['to', 'foot,', 'things'],
#  'best to': ['return'],
#  'to return': ['the', 'with', 'to', 'to'],
#  'return the': ['great'],
#  ...}

# %%
if __name__ == '__main__':
    url = 'http://www.gutenberg.org/cache/epub/61995/pg61995.txt'
    words = gatherBook(url)
    
    markovDict = make_markov_dict(words, 2)
    ml = list(enumerate(markovDict.items()))
    print(ml[200:210])
# Out:
# [(200, ('and say,', ['Obey'])), (201, ('say, Obey', ['and'])), (202, ('Obey and', ['please'])), (203, ('and please', ['my', 'come'])), (204, ('please my', ['lord'])), (205, ('my lord', ['and'])), (206, ('lord and', ['lady,'])), (207, ('and lady,', ['So'])), (208, ('lady, So', ['God'])), (209, ('So God', ['shall']))]

# %%
def generate_suffixes(markovDict, prefix):
    '''
    Parameters
    markovDict : dict
        dictionary created using function make_markov_dict
    prefix : str
        prefix that you would like to generate suffixes for

    Returns
    sortedTups : list of tuples
        list of sorted tuples containing (suffix, count), corresponding to prefix input.
    alternatively, if you argue a prefix that is not present in markovDict, then a message will alert you
    '''

    tupList = []
    seenList = []
    try:
        for _ in markovDict[prefix]:
            if _ not in seenList:
                seenList.append(_)
                tupList.append((_, markovDict[prefix].count(_)))
                # this list of tuples does not HAVE to be sorted, but it's useful if we want 
                # to quickly visualize the frequency of suffixes for a given prefix
        sortedTups = sorted(tupList, key = lambda x: x[1], reverse = True)
        
        return sortedTups

    except (KeyError):
        return f'"{prefix}" is not present as a key in your markov Dictionary'

# %%
if __name__ == '__main__':
    url = 'http://www.gutenberg.org/cache/epub/61995/pg61995.txt'
    words = gatherBook(url)
    
    markovDict = make_markov_dict(words, 2)
    
    sortedTups = generate_suffixes(markovDict, 'He said')
    print(sortedTups)
# Out:
# [('he', 2), ('to', 1), ('his', 1), ('that', 1)]

# %%
sortedTups = generate_suffixes(markovDict, 'yolo ay')
print(sortedTups)
# Out:
# "yolo ay" is not present as a key in your markov Dictionary

# %%
def predict_sentence(cleansed_words, prefix, n):
    '''
    Parameters
    cleansed_words : list
        List of words from text with whitespace and punctuation removed (though the function will also accept words with punctuation).
    prefix : str
        String you want your generated sentence to begin with.
    n : int
        Number of times you want predict_sentence to predict a suffix.

    Returns
    sentence : str
        Predicted sentence with n suffixes predicted.

    '''
    multiDict = make_markov_dict(cleansed_words, len(prefix.split()))
    prefix = prefix.lower()
    # we convert to lower because our cleanse function automatically converts to lower
    sentence = prefix #initialize our sentence to just be our prefix
    
    for _ in range(n-1):
        sortedTups = generate_suffixes(multiDict, prefix) #find suffixes for our prefix from multiDict
        words, nums = list(zip(*sortedTups)) #doing this to produce a list of frequences we can use for np.random.choice
        denom = sum(nums)
        probs = [_ / denom for _ in nums]
        suffix = np.random.choice(words, p = probs) 
        #select suffix based on probability of being chosen
        #np.random.choice is useful here because it maps list of words to list of thier frequencies (probs)
        sentence = sentence + ' ' +  suffix #add suffix to our sentence
        
        prefix = sentence.split()[-len(prefix.split()):] # redefining prefix by dropping first word from previous prefix
        prefix = (' ').join(prefix)
        
    return sentence

# %%
if __name__ == '__main__':
    url = 'http://www.gutenberg.org/cache/epub/63632/pg63632.txt'
    words = gatherBook(url)

    cleansedWords = [cleanse(word) for word in words]

    print(predict_sentence(cleansedWords, 'he said', 10)) 
    # this will predict an 11-word sentence (first input word, plus 10 suffixes)
# Out:
# he said slowly this is for me mr mulhane the allied

# %% [markdown]
# ### N Gram

# %%
import re
import nltk
import random
import urllib.request
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anies\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anies\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text.lower())
    
    # Removing stopwords and punctuation
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and re.match(r'^\w+$', token)]
    
    return tokens

# %%
def build_ngram_model(tokens, n=2):
    ngram_model = {}
    for i in range(len(tokens)-n):
        gram = ' '.join(tokens[i:i+n])
        next_token = tokens[i+n]
        if gram not in ngram_model:
            ngram_model[gram] = []
        ngram_model[gram].append(next_token)
    return ngram_model

# %%
def generate_text(ngram_model, seed_text, max_length=50):
    current_text = seed_text.lower()
    n = len(seed_text.split())
    for _ in range(max_length):
        last_n_tokens = current_text.split()[-n:]
        last_n_gram = ' '.join(last_n_tokens)
        if last_n_gram in ngram_model:
            next_token = random.choice(ngram_model[last_n_gram])
            current_text += ' ' + next_token
        else:
            break
    return current_text.capitalize()

# %%
# Acquire data from the URL
url = 'http://www.gutenberg.org/cache/epub/61995/pg61995.txt'
with urllib.request.urlopen(url) as file_object:
    text = file_object.read().decode('utf-8-sig').split('***')[2]

# Preprocess the text
tokens = preprocess_text(text)

# %%
ngram_model = build_ngram_model(tokens, n=2)  # Adjust n-gram size as needed
seed_text = "The"
generated_text = generate_text(ngram_model, seed_text, max_length=100)  # Adjust max_length as needed
print("Generated Text:")
print(generated_text)
# Out:
# Generated Text:
# The
